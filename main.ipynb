# %%
import torch

# %%
checkpoint = torch.load("insane.pt")
# Out:
# /home/pierre/robotic/.venv/lib/python3.13/site-packages/torch/cuda/__init__.py:829: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
checkpoint
# Out:
# {'epoch': 99,
#  'model_state_dict': OrderedDict([('vision_encoder.cls_token',
#                tensor([[[-7.5947e-02, -3.6638e-03,  1.4773e-02,  1.5319e-02,  9.1802e-03,
#                           3.3578e-02, -1.5030e-03, -1.4542e-02,  1.4590e-02, -4.9383e-03,
#                           2.0321e-02, -2.9293e-02, -2.2206e-03, -3.6527e-02,  2.8393e-03,
#                           2.5249e-02, -3.4337e-02, -4.2720e-02,  2.7450e-02, -7.7383e-03,
#                           3.2208e-02, -9.0322e-03, -1.1916e-03,  1.7760e-02,  2.1696e-02,
#                          -1.9011e-02,  1.4123e-02, -2.1351e-02, -3.0849e-02,  9.1063e-03,
#                           2.7476e-02,  9.7530e-03, -2.4224e-02, -3.3229e-03,  1.8432e-02,
#                          -1.0421e-02, -7.4427e-03,  2.7093e-03, -1.5945e-02, -1.8464e-02,
#                          -1.1993e-02, -2.9957e-02, -2.4668e-02, -4.3417e-02, -1.6722e-02,
# ...
