# %%
from collections import defaultdict

import h5py
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim.lr_scheduler import OneCycleLR
from torch.utils.data import DataLoader, Dataset

# %%
DATASET_PATH = "dataset-distance.h5"
DEVICE = torch.device("cuda:2")
BATCH_SIZE = 256

print(f"Using device: {DEVICE}")
# Out:
# Using device: cuda:2

# %%
def move_to_device(batch):
    return tuple(item.to(DEVICE, non_blocking=True) for item in batch)

# %%
def augment_batch(depth, mask, quat):
    batch_size = depth.shape[0]

    # Gaussian noise
    if torch.rand(1).item() < 0.5:
        noise = torch.randn_like(depth) * 0.02
        depth = depth + noise

    # Scale variations
    if torch.rand(1).item() < 0.5:
        scales = torch.empty(batch_size, 1, 1, device=DEVICE).uniform_(0.95, 1.05)
        depth = depth * scales

    # Small per-sample offset
    if torch.rand(1).item() < 0.3:
        offsets = torch.empty(batch_size, 1, 1, device=DEVICE).uniform_(-0.03, 0.03)
        depth = depth + offsets

    depth = torch.clamp(depth, 0, 1)

    # Mask augmentation
    if torch.rand(1).item() < 0.4:
        mask_4d = mask.unsqueeze(1)
        if torch.rand(1).item() < 0.8:
            mask_4d = F.max_pool2d(mask_4d, 3, stride=1, padding=1)
        else:
            mask_4d = -F.max_pool2d(-mask_4d, 3, stride=1, padding=1)
        mask = mask_4d.squeeze(1)

    # Quaternion augmentation
    if torch.rand(1).item() < 0.5:
        angles = torch.empty(batch_size, device=DEVICE).uniform_(-0.175, 0.175)
        half_angles = angles / 2

        perturb_quats = torch.stack(
            [torch.cos(half_angles), torch.zeros_like(half_angles), torch.zeros_like(half_angles), torch.sin(half_angles)], dim=1
        )

        w1, x1, y1, z1 = perturb_quats.unbind(1)
        w2, x2, y2, z2 = quat.unbind(1)

        quat = torch.stack(
            [
                w1 * w2 - x1 * x2 - y1 * y2 - z1 * z2,
                w1 * x2 + x1 * w2 + y1 * z2 - z1 * y2,
                w1 * y2 - x1 * z2 + y1 * w2 + z1 * x2,
                w1 * z2 + x1 * y2 - y1 * x2 + z1 * w2,
            ],
            dim=1,
        )

        quat = F.normalize(quat, dim=1)

    return depth, mask, quat

# %%
class DistanceDataset(Dataset):
    def __init__(self):
        self._h5_file = None
        with h5py.File(DATASET_PATH, "r") as f:
            self.keys = list(f.keys())
            self.primitives = list(f.attrs["primitives"])
            self.depth_min = f.attrs["depth_min"]
            self.depth_max = f.attrs["depth_max"]
            self.dist_max = f.attrs["dist_max"]

    def _init_h5(self):
        if self._h5_file is None:
            self._h5_file = h5py.File(DATASET_PATH, "r")

    def close(self):
        if self._h5_file is not None:
            self._h5_file.close()
            self._h5_file = None

    def __del__(self):
        self.close()

    def __len__(self):
        return len(self.keys)

    def __getitem__(self, idx):
        self._init_h5()
        dp = self._h5_file[self.keys[idx]]
        return dp["depth"][()], dp["mask"][()], dp["dist_map"][()], dp["quat"][()], dp["feasibles"][()]

# %%
dataset = DistanceDataset()
primitives = dataset.primitives
num_primitives = len(primitives)

scene_to_indices = defaultdict(list)
for idx, key in enumerate(dataset.keys):
    scene_to_indices[key.rsplit("_obj_", 1)[0]].append(idx)
scene_ids = list(scene_to_indices.keys())


num_train = int(len(scene_ids) * 0.8)
num_val = int(len(scene_ids) * 0.1)
train_scenes = scene_ids[:num_train]
val_scenes = scene_ids[num_train : num_train + num_val]
test_scenes = scene_ids[num_train + num_val :]

train_indices = [idx for scene in train_scenes for idx in scene_to_indices[scene]]
val_indices = [idx for scene in val_scenes for idx in scene_to_indices[scene]]
test_indices = [idx for scene in test_scenes for idx in scene_to_indices[scene]]

train_dataset = torch.utils.data.Subset(dataset, train_indices)
val_dataset = torch.utils.data.Subset(dataset, val_indices)
test_dataset = torch.utils.data.Subset(dataset, test_indices)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=4, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=4, pin_memory=True)

print(f"Total scenes: {len(scene_ids)}")
print(f"Train: {len(train_scenes)} scenes, {len(train_indices)} samples")
print(f"Val: {len(val_scenes)} scenes, {len(val_indices)} samples")
print(f"Test: {len(test_scenes)} scenes, {len(test_indices)} samples")
print(f"Sample shapes: {[item.shape for item in dataset[0]]}")
# Out:
# Total scenes: 10996
# Train: 8796 scenes, 39784 samples
# Val: 1099 scenes, 4915 samples
# Test: 1101 scenes, 4995 samples
# Sample shapes: [(256, 384), (256, 384), (256, 384), (4,), (8,)]

# %%
pos_counts = torch.zeros(num_primitives)
neg_counts = torch.zeros(num_primitives)
with h5py.File(DATASET_PATH, "r") as f:
    for key in dataset.keys:
        feasibles = torch.from_numpy(f[key]["feasibles"][()])
        pos_counts += feasibles
        neg_counts += 1 - feasibles
alpha = neg_counts / (pos_counts + neg_counts)
alpha = alpha.to(DEVICE)
print(f"Alpha: {alpha}")
# Out:
# /home/pierre/robotic/.venv/lib/python3.13/site-packages/torch/cuda/__init__.py:829: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# Alpha: tensor([0.8307, 0.8268, 0.8255, 0.8309, 0.5378, 0.5309, 0.5987, 0.5940],
#        device='cuda:2')

# %%
class FocalLoss(nn.Module):
    def __init__(self, alpha=0.25, gamma=2.0):
        super().__init__()
        self.alpha = alpha
        self.gamma = gamma

    def forward(self, logits, targets):
        bce_loss = nn.functional.binary_cross_entropy_with_logits(logits, targets, reduction="none")
        probs = torch.sigmoid(logits)
        pt = torch.where(targets == 1, probs, 1 - probs)
        focal_weight = (1 - pt) ** self.gamma
        alpha_weight = torch.where(targets == 1, self.alpha, 1 - self.alpha)
        loss = alpha_weight * focal_weight * bce_loss
        return loss.mean()

# %%
def compute_metrics(probs: torch.Tensor, targets: torch.Tensor, threshold=0.5):
    preds = (probs > threshold).float()
    accuracy = (preds == targets).float().mean(dim=0)

    tp = (preds * targets).sum(dim=0)
    fp = (preds * (1 - targets)).sum(dim=0)
    fn = ((1 - preds) * targets).sum(dim=0)

    precision = tp / (tp + fp + 1e-8)
    recall = tp / (tp + fn + 1e-8)
    f1 = 2 * precision * recall / (precision + recall + 1e-8)

    prob_mean = probs.mean(dim=0)
    prob_std = probs.std(dim=0)

    return accuracy, precision, recall, f1, prob_mean, prob_std

# %%
class ConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3, stride=1, padding=1):
        super().__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding)
        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        return self.relu(self.conv(x))


class DistanceCNN(nn.Module):
    def __init__(self, num_primitives):
        super().__init__()

        self.conv1 = ConvBlock(3, 16, kernel_size=7, stride=2, padding=3)  # 128x192
        self.conv2 = ConvBlock(16, 32, kernel_size=3, stride=2, padding=1)  # 64x96
        self.conv3 = ConvBlock(32, 64, kernel_size=3, stride=2, padding=1)  # 32x48

        self.pool = nn.AdaptiveAvgPool2d((8, 12))  # 8x12
        self.dropout = nn.Dropout(0.2)

        vision_feat_dim = 64 * 8 * 12

        self.quat_encoder = nn.Sequential(
            nn.Linear(4, 64),
            nn.GELU(),
            nn.Dropout(0.2),
        )

        self.classifier = nn.Sequential(
            nn.Linear(vision_feat_dim + 64, 512),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, num_primitives),
        )

    def forward(self, depth, mask, goal, quat):
        x = torch.stack([depth, mask, goal], dim=1)

        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)

        x = self.pool(x)
        x = self.dropout(x)
        vision_feat = x.flatten(1)

        quat_feat = self.quat_encoder(quat)

        return self.classifier(torch.cat([vision_feat, quat_feat], dim=1))

# %%
model = DistanceCNN(8).to(DEVICE)
print(f"Model parameters: {sum(p.numel() for p in model.parameters() if p.requires_grad):,}")

criterion = FocalLoss(alpha=alpha, gamma=2.0)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3, weight_decay=1e-4)
scheduler = OneCycleLR(optimizer, max_lr=2e-4, epochs=100, steps_per_epoch=len(train_loader), pct_start=0.2, anneal_strategy="cos")
# Out:
# Model parameters: 3,338,216

# %%
def check_grad_norms():
    for name, param in model.named_parameters():
        if param.grad is not None:
            grad_norm = param.grad.norm().item()
            if grad_norm < 1e-7 or grad_norm > 5e-1:
                print(f"{name:50s} | grad_norm: {grad_norm:.2e}")


@torch.no_grad()
def debug_model():
    model.eval()
    batch = next(iter(train_loader))
    depth, mask, dist_map, quat, _ = move_to_device(batch)

    vision_input = torch.stack([depth, mask, dist_map], dim=1)

    conv1_out = model.conv1(vision_input)
    conv2_out = model.conv2(conv1_out)
    conv3_out = model.conv3(conv2_out)
    pooled = model.pool(conv3_out)

    quat_feat = model.quat_encoder(quat)
    logits = model(depth, mask, dist_map, quat)

    depth_impact = (logits - model(torch.zeros_like(depth), mask, dist_map, quat)).abs().mean()
    mask_impact = (logits - model(depth, torch.zeros_like(mask), dist_map, quat)).abs().mean()
    dist_impact = (logits - model(depth, mask, torch.zeros_like(dist_map), quat)).abs().mean()
    quat_impact = (logits - model(depth, mask, dist_map, torch.zeros_like(quat))).abs().mean()

    conv_dead = (pooled.abs() < 1e-5).float().mean()
    quat_dead = (quat_feat.abs() < 1e-5).float().mean()

    print(
        f"impacts: d={depth_impact:.3f} m={mask_impact:.3f} "
        f"dist={dist_impact:.3f} q={quat_impact:.3f} | "
        f"std: c1={conv1_out.std():.3f} c2={conv2_out.std():.3f} "
        f"c3={conv3_out.std():.3f} c4={conv3_out.std():.3f} "
        f"pool={pooled.std():.3f} quat={quat_feat.std():.3f} "
        f"logit={logits.std():.3f} | "
        f"dead: conv={conv_dead:.2f} q={quat_dead:.2f}"
    )

# %%
def train():
    model.train()
    total_loss = 0.0
    for batch in train_loader:
        depth, mask, goal, quat, y = move_to_device(batch)
        depth, mask, quat = augment_batch(depth, mask, quat)
        optimizer.zero_grad()
        logits = model(depth, mask, goal, quat)
        loss = criterion(logits, y)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=0.5)
        optimizer.step()
        scheduler.step()
        total_loss += loss.item() * depth.size(0)
    return total_loss / len(train_loader.dataset)


@torch.no_grad()
def val():
    model.eval()
    val_loss = 0.0
    preds, targets = [], []
    for batch in val_loader:
        depth, mask, goal, quat, y = move_to_device(batch)
        pred = model(depth, mask, goal, quat)
        loss = criterion(pred, y)
        val_loss += loss.item() * depth.size(0)
        preds.append(pred)
        targets.append(y)
    return val_loss / len(val_loader.dataset), torch.cat(preds), torch.cat(targets)

# %%
best_f1 = 0.0
patience = 5
patience_counter = 0
best_model_state = None

debug_model()

for epoch in range(100):
    lr = scheduler.get_last_lr()[0]
    train_loss = train()
    val_loss, logits, targets = val()

    print(f"epoch {epoch + 1:02d}: tL={train_loss:.4f} vL={val_loss:.4f} lr={lr:.2e}")

    acc, prec, rec, f1, prob_mean, prob_std = compute_metrics(logits.sigmoid(), targets)
    for i, primitive in enumerate(primitives):
        print(f"  {primitive:<12} A={acc[i]:.3f} P={prec[i]:.3f} R={rec[i]:.3f} F1={f1[i]:.3f} M={prob_mean[i]:.3f} S={prob_std[i]:.3f}")

    avg_f1 = f1.mean().item()
    if avg_f1 > best_f1:
        best_f1 = avg_f1
        patience_counter = 0
        best_model_state = {k: v.cpu().clone() for k, v in model.state_dict().items()}
    else:
        patience_counter += 1
        if patience_counter >= patience:
            checkpoint = {
                "epoch": epoch,
                "model_state_dict": model.state_dict(),
                "optimizer_state_dict": optimizer.state_dict(),
                "scheduler_state_dict": scheduler.state_dict(),
                "val_loss": val_loss,
                "avg_f1": avg_f1,
            }

            torch.save(checkpoint, f"cnn-model-{epoch}.pt")
            patience_counter = 0

    debug_model()
    check_grad_norms()
# Out:
# impacts: d=0.001 m=0.000 dist=0.001 q=0.001 | std: c1=0.124 c2=0.058 c3=0.031 c4=0.031 pool=0.030 quat=0.206 logit=0.031 | dead: conv=0.41 q=0.00
# epoch 01: tL=0.0671 vL=0.0670 lr=8.00e-06
#   push_x_pos   A=0.837 P=0.000 R=0.000 F1=0.000 M=0.494 S=0.001
#   push_x_neg   A=0.824 P=0.000 R=0.000 F1=0.000 M=0.497 S=0.000
#   push_y_pos   A=0.175 P=0.175 R=1.000 F1=0.297 M=0.502 S=0.001
#   push_y_neg   A=0.834 P=0.000 R=0.000 F1=0.000 M=0.497 S=0.000
#   lift_x       A=0.466 P=0.464 R=0.984 F1=0.630 M=0.501 S=0.000
#   lift_y       A=0.529 P=0.512 R=0.258 F1=0.343 M=0.500 S=0.000
#   pull_x       A=0.519 P=0.403 R=0.444 F1=0.422 M=0.500 S=0.001
#   pull_y       A=0.583 P=0.492 R=0.045 F1=0.082 M=0.499 S=0.000
# impacts: d=0.002 m=0.000 dist=0.001 q=0.002 | std: c1=0.127 c2=0.062 c3=0.033 c4=0.033 pool=0.033 quat=0.206 logit=0.009 | dead: conv=0.39 q=0.00
# epoch 02: tL=0.0670 vL=0.0670 lr=9.18e-06
#   push_x_pos   A=0.739 P=0.110 R=0.085 F1=0.096 M=0.499 S=0.001
#   push_x_neg   A=0.345 P=0.195 R=0.870 F1=0.319 M=0.501 S=0.001
#   push_y_pos   A=0.453 P=0.201 R=0.717 F1=0.314 M=0.501 S=0.002
#   push_y_neg   A=0.834 P=0.000 R=0.000 F1=0.000 M=0.498 S=0.001
#   lift_x       A=0.503 P=0.479 R=0.835 F1=0.608 M=0.501 S=0.001
#   lift_y       A=0.532 P=0.543 R=0.113 F1=0.187 M=0.499 S=0.001
#   pull_x       A=0.488 P=0.391 R=0.526 F1=0.449 M=0.500 S=0.001
#   pull_y       A=0.583 P=0.000 R=0.000 F1=0.000 M=0.498 S=0.001
# impacts: d=0.004 m=0.000 dist=0.002 q=0.004 | std: c1=0.127 c2=0.063 c3=0.034 c4=0.034 pool=0.034 quat=0.204 logit=0.007 | dead: conv=0.36 q=0.00
# epoch 03: tL=0.0670 vL=0.0669 lr=1.27e-05
#   push_x_pos   A=0.837 P=0.000 R=0.000 F1=0.000 M=0.498 S=0.001
#   push_x_neg   A=0.763 P=0.277 R=0.213 F1=0.241 M=0.498 S=0.002
#   push_y_pos   A=0.416 P=0.209 R=0.840 F1=0.334 M=0.502 S=0.004
#   push_y_neg   A=0.500 P=0.208 R=0.717 F1=0.323 M=0.500 S=0.002
#   lift_x       A=0.551 P=0.568 R=0.120 F1=0.198 M=0.497 S=0.002
#   lift_y       A=0.504 P=0.489 R=0.886 F1=0.630 M=0.502 S=0.001
#   pull_x       A=0.527 P=0.417 R=0.487 F1=0.449 M=0.500 S=0.002
#   pull_y       A=0.486 P=0.436 R=0.788 F1=0.561 M=0.501 S=0.002
# impacts: d=0.019 m=0.002 dist=0.009 q=0.006 | std: c1=0.123 c2=0.063 c3=0.035 c4=0.035 pool=0.033 quat=0.208 logit=0.011 | dead: conv=0.33 q=0.00
# epoch 04: tL=0.0668 vL=0.0661 lr=1.85e-05
#   push_x_pos   A=0.399 P=0.204 R=0.927 F1=0.334 M=0.503 S=0.004
#   push_x_neg   A=0.457 P=0.207 R=0.732 F1=0.323 M=0.504 S=0.008
#   push_y_pos   A=0.506 P=0.212 R=0.674 F1=0.323 M=0.501 S=0.011
#   push_y_neg   A=0.742 P=0.195 R=0.177 F1=0.186 M=0.492 S=0.008
#   lift_x       A=0.596 P=0.564 R=0.550 F1=0.557 M=0.496 S=0.015
#   lift_y       A=0.595 P=0.565 R=0.654 F1=0.606 M=0.500 S=0.014
#   pull_x       A=0.571 P=0.469 R=0.622 F1=0.535 M=0.500 S=0.011
#   pull_y       A=0.553 P=0.476 R=0.721 F1=0.574 M=0.504 S=0.012
# impacts: d=0.161 m=0.043 dist=0.045 q=0.011 | std: c1=0.131 c2=0.080 c3=0.066 c4=0.066 pool=0.055 quat=0.208 logit=0.048 | dead: conv=0.27 q=0.00
# epoch 05: tL=0.0652 vL=0.0634 lr=2.63e-05
#   push_x_pos   A=0.505 P=0.227 R=0.852 F1=0.359 M=0.503 S=0.013
#   push_x_neg   A=0.661 P=0.260 R=0.498 F1=0.342 M=0.493 S=0.018
#   push_y_pos   A=0.624 P=0.231 R=0.494 F1=0.315 M=0.490 S=0.024
#   push_y_neg   A=0.622 P=0.201 R=0.430 F1=0.274 M=0.489 S=0.025
#   lift_x       A=0.623 P=0.568 R=0.770 F1=0.653 M=0.511 S=0.052
#   lift_y       A=0.632 P=0.583 R=0.799 F1=0.674 M=0.514 S=0.056
#   pull_x       A=0.589 P=0.488 R=0.779 F1=0.600 M=0.509 S=0.050
#   pull_y       A=0.588 P=0.503 R=0.797 F1=0.617 M=0.514 S=0.054
# impacts: d=0.810 m=0.194 dist=0.127 q=0.024 | std: c1=0.143 c2=0.108 c3=0.148 c4=0.148 pool=0.116 quat=0.208 logit=0.167 | dead: conv=0.25 q=0.00
# epoch 06: tL=0.0631 vL=0.0610 lr=3.61e-05
#   push_x_pos   A=0.666 P=0.285 R=0.702 F1=0.406 M=0.488 S=0.028
#   push_x_neg   A=0.692 P=0.331 R=0.736 F1=0.457 M=0.493 S=0.029
#   push_y_pos   A=0.572 P=0.264 R=0.811 F1=0.398 M=0.493 S=0.050
#   push_y_neg   A=0.618 P=0.276 R=0.798 F1=0.410 M=0.489 S=0.050
#   lift_x       A=0.645 P=0.602 R=0.688 F1=0.642 M=0.497 S=0.064
#   lift_y       A=0.650 P=0.614 R=0.716 F1=0.661 M=0.498 S=0.067
#   pull_x       A=0.617 P=0.512 R=0.700 F1=0.591 M=0.497 S=0.062
#   pull_y       A=0.620 P=0.533 R=0.715 F1=0.611 M=0.500 S=0.064
# impacts: d=1.550 m=0.240 dist=0.230 q=0.067 | std: c1=0.143 c2=0.112 c3=0.173 c4=0.173 pool=0.134 quat=0.214 logit=0.227 | dead: conv=0.27 q=0.00
# epoch 07: tL=0.0609 vL=0.0584 lr=4.76e-05
#   push_x_pos   A=0.663 P=0.317 R=0.927 F1=0.472 M=0.479 S=0.072
#   push_x_neg   A=0.751 P=0.390 R=0.738 F1=0.511 M=0.472 S=0.069
#   push_y_pos   A=0.681 P=0.345 R=0.916 F1=0.501 M=0.477 S=0.092
#   push_y_neg   A=0.731 P=0.363 R=0.821 F1=0.504 M=0.458 S=0.096
#   lift_x       A=0.640 P=0.584 R=0.774 F1=0.666 M=0.509 S=0.067
#   lift_y       A=0.642 P=0.589 R=0.825 F1=0.687 M=0.519 S=0.071
#   pull_x       A=0.608 P=0.504 R=0.768 F1=0.608 M=0.506 S=0.066
#   pull_y       A=0.599 P=0.512 R=0.813 F1=0.628 M=0.518 S=0.069
# impacts: d=2.079 m=0.264 dist=0.392 q=0.155 | std: c1=0.144 c2=0.112 c3=0.181 c4=0.181 pool=0.140 quat=0.228 logit=0.334 | dead: conv=0.28 q=0.00
# epoch 08: tL=0.0582 vL=0.0551 lr=6.04e-05
#   push_x_pos   A=0.728 P=0.368 R=0.937 F1=0.529 M=0.443 S=0.128
#   push_x_neg   A=0.780 P=0.434 R=0.810 F1=0.565 M=0.445 S=0.119
#   push_y_pos   A=0.769 P=0.424 R=0.908 F1=0.578 M=0.433 S=0.131
#   push_y_neg   A=0.750 P=0.395 R=0.950 F1=0.558 M=0.444 S=0.134
#   lift_x       A=0.647 P=0.595 R=0.742 F1=0.660 M=0.500 S=0.072
#   lift_y       A=0.654 P=0.615 R=0.738 F1=0.670 M=0.502 S=0.076
#   pull_x       A=0.618 P=0.512 R=0.743 F1=0.606 M=0.501 S=0.070
#   pull_y       A=0.627 P=0.538 R=0.742 F1=0.624 M=0.503 S=0.073
# impacts: d=2.629 m=0.344 dist=0.495 q=0.251 | std: c1=0.143 c2=0.112 c3=0.188 c4=0.188 pool=0.146 quat=0.235 logit=0.471 | dead: conv=0.30 q=0.00
# epoch 09: tL=0.0554 vL=0.0527 lr=7.44e-05
#   push_x_pos   A=0.783 P=0.426 R=0.972 F1=0.593 M=0.431 S=0.154
#   push_x_neg   A=0.819 P=0.493 R=0.947 F1=0.648 M=0.423 S=0.139
#   push_y_pos   A=0.803 P=0.469 R=0.967 F1=0.632 M=0.422 S=0.153
#   push_y_neg   A=0.813 P=0.469 R=0.968 F1=0.632 M=0.423 S=0.156
#   lift_x       A=0.643 P=0.593 R=0.724 F1=0.652 M=0.503 S=0.061
#   lift_y       A=0.654 P=0.614 R=0.739 F1=0.670 M=0.505 S=0.066
#   pull_x       A=0.627 P=0.522 R=0.717 F1=0.604 M=0.501 S=0.058
#   pull_y       A=0.627 P=0.540 R=0.716 F1=0.615 M=0.504 S=0.064
# impacts: d=2.963 m=0.401 dist=0.579 q=0.306 | std: c1=0.145 c2=0.112 c3=0.190 c4=0.190 pool=0.149 quat=0.241 logit=0.538 | dead: conv=0.34 q=0.00
# epoch 10: tL=0.0526 vL=0.0497 lr=8.90e-05
#   push_x_pos   A=0.866 P=0.548 R=0.987 F1=0.705 M=0.392 S=0.193
#   push_x_neg   A=0.847 P=0.536 R=0.970 F1=0.690 M=0.393 S=0.183
#   push_y_pos   A=0.856 P=0.549 R=0.986 F1=0.706 M=0.396 S=0.196
#   push_y_neg   A=0.877 P=0.576 R=0.971 F1=0.723 M=0.375 S=0.196
#   lift_x       A=0.635 P=0.573 R=0.826 F1=0.677 M=0.517 S=0.060
#   lift_y       A=0.655 P=0.612 R=0.758 F1=0.677 M=0.507 S=0.067
#   pull_x       A=0.607 P=0.502 R=0.814 F1=0.621 M=0.514 S=0.059
#   pull_y       A=0.617 P=0.528 R=0.767 F1=0.625 M=0.509 S=0.065
# impacts: d=3.261 m=0.473 dist=0.735 q=0.450 | std: c1=0.144 c2=0.109 c3=0.184 c4=0.184 pool=0.144 quat=0.251 logit=0.758 | dead: conv=0.35 q=0.00
# epoch 11: tL=0.0505 vL=0.0487 lr=1.04e-04
#   push_x_pos   A=0.905 P=0.633 R=0.992 F1=0.773 M=0.342 S=0.220
#   push_x_neg   A=0.878 P=0.593 R=0.987 F1=0.741 M=0.376 S=0.214
#   push_y_pos   A=0.894 P=0.623 R=0.990 F1=0.765 M=0.352 S=0.221
#   push_y_neg   A=0.901 P=0.630 R=0.977 F1=0.766 M=0.348 S=0.217
#   lift_x       A=0.609 P=0.548 R=0.885 F1=0.677 M=0.537 S=0.065
#   lift_y       A=0.638 P=0.584 R=0.832 F1=0.687 M=0.528 S=0.072
#   pull_x       A=0.575 P=0.480 R=0.865 F1=0.617 M=0.531 S=0.064
#   pull_y       A=0.595 P=0.508 R=0.834 F1=0.632 M=0.528 S=0.070
# impacts: d=3.485 m=0.560 dist=0.900 q=0.552 | std: c1=0.142 c2=0.107 c3=0.181 c4=0.181 pool=0.140 quat=0.256 logit=0.978 | dead: conv=0.36 q=0.00
# epoch 12: tL=0.0489 vL=0.0467 lr=1.19e-04
#   push_x_pos   A=0.916 P=0.660 R=0.996 F1=0.794 M=0.312 S=0.237
#   push_x_neg   A=0.890 P=0.619 R=0.980 F1=0.759 M=0.338 S=0.234
#   push_y_pos   A=0.899 P=0.636 R=0.992 F1=0.775 M=0.330 S=0.236
#   push_y_neg   A=0.914 P=0.666 R=0.974 F1=0.791 M=0.318 S=0.230
#   lift_x       A=0.639 P=0.574 R=0.849 F1=0.685 M=0.524 S=0.071
#   lift_y       A=0.643 P=0.588 R=0.835 F1=0.690 M=0.525 S=0.079
#   pull_x       A=0.607 P=0.502 R=0.853 F1=0.632 M=0.523 S=0.071
#   pull_y       A=0.619 P=0.527 R=0.817 F1=0.641 M=0.520 S=0.078
# impacts: d=3.783 m=0.607 dist=0.978 q=0.651 | std: c1=0.140 c2=0.105 c3=0.173 c4=0.173 pool=0.136 quat=0.257 logit=1.112 | dead: conv=0.36 q=0.00
# epoch 13: tL=0.0476 vL=0.0452 lr=1.34e-04
#   push_x_pos   A=0.918 P=0.665 R=0.996 F1=0.798 M=0.299 S=0.255
#   push_x_neg   A=0.899 P=0.637 R=0.992 F1=0.775 M=0.319 S=0.257
#   push_y_pos   A=0.908 P=0.657 R=0.993 F1=0.791 M=0.317 S=0.254
#   push_y_neg   A=0.919 P=0.675 R=0.984 F1=0.801 M=0.301 S=0.247
#   lift_x       A=0.652 P=0.588 R=0.824 F1=0.686 M=0.516 S=0.070
#   lift_y       A=0.666 P=0.620 R=0.775 F1=0.689 M=0.510 S=0.077
#   pull_x       A=0.640 P=0.530 R=0.804 F1=0.639 M=0.508 S=0.071
#   pull_y       A=0.649 P=0.556 R=0.778 F1=0.649 M=0.507 S=0.076
# impacts: d=3.816 m=0.684 dist=1.086 q=0.762 | std: c1=0.139 c2=0.103 c3=0.165 c4=0.165 pool=0.127 quat=0.264 logit=1.275 | dead: conv=0.39 q=0.00
# epoch 14: tL=0.0467 vL=0.0443 lr=1.48e-04
#   push_x_pos   A=0.922 P=0.675 R=0.999 F1=0.806 M=0.290 S=0.256
#   push_x_neg   A=0.907 P=0.655 R=0.995 F1=0.790 M=0.305 S=0.261
#   push_y_pos   A=0.914 P=0.672 R=0.994 F1=0.802 M=0.294 S=0.253
#   push_y_neg   A=0.920 P=0.677 R=0.993 F1=0.805 M=0.311 S=0.252
#   lift_x       A=0.674 P=0.629 R=0.717 F1=0.670 M=0.496 S=0.073
#   lift_y       A=0.685 P=0.643 R=0.760 F1=0.697 M=0.505 S=0.077
#   pull_x       A=0.667 P=0.563 R=0.710 F1=0.628 M=0.493 S=0.073
#   pull_y       A=0.669 P=0.581 R=0.731 F1=0.648 M=0.498 S=0.077
# impacts: d=3.896 m=0.733 dist=1.105 q=0.825 | std: c1=0.139 c2=0.105 c3=0.163 c4=0.163 pool=0.128 quat=0.264 logit=1.320 | dead: conv=0.39 q=0.00
# epoch 15: tL=0.0461 vL=0.0438 lr=1.60e-04
#   push_x_pos   A=0.923 P=0.679 R=0.997 F1=0.808 M=0.265 S=0.261
#   push_x_neg   A=0.906 P=0.653 R=0.999 F1=0.790 M=0.295 S=0.268
#   push_y_pos   A=0.915 P=0.675 R=0.992 F1=0.803 M=0.278 S=0.260
#   push_y_neg   A=0.925 P=0.692 R=0.989 F1=0.815 M=0.284 S=0.257
#   lift_x       A=0.678 P=0.629 R=0.738 F1=0.679 M=0.495 S=0.082
#   lift_y       A=0.682 P=0.644 R=0.745 F1=0.691 M=0.498 S=0.091
#   pull_x       A=0.670 P=0.566 R=0.715 F1=0.632 M=0.488 S=0.086
#   pull_y       A=0.669 P=0.580 R=0.746 F1=0.652 M=0.495 S=0.092
# impacts: d=4.194 m=0.800 dist=1.216 q=0.901 | std: c1=0.138 c2=0.108 c3=0.160 c4=0.160 pool=0.126 quat=0.266 logit=1.512 | dead: conv=0.41 q=0.00
# epoch 16: tL=0.0453 vL=0.0458 lr=1.72e-04
#   push_x_pos   A=0.921 P=0.675 R=0.999 F1=0.805 M=0.282 S=0.267
#   push_x_neg   A=0.909 P=0.662 R=0.995 F1=0.795 M=0.282 S=0.269
#   push_y_pos   A=0.916 P=0.676 R=0.995 F1=0.805 M=0.287 S=0.263
#   push_y_neg   A=0.925 P=0.691 R=0.995 F1=0.815 M=0.281 S=0.256
#   lift_x       A=0.625 P=0.559 R=0.898 F1=0.689 M=0.536 S=0.064
#   lift_y       A=0.618 P=0.560 R=0.931 F1=0.699 M=0.550 S=0.069
#   pull_x       A=0.606 P=0.501 R=0.887 F1=0.641 M=0.528 S=0.068
#   pull_y       A=0.585 P=0.501 R=0.929 F1=0.651 M=0.547 S=0.072
# impacts: d=3.413 m=0.785 dist=1.172 q=0.908 | std: c1=0.138 c2=0.108 c3=0.138 c4=0.138 pool=0.106 quat=0.268 logit=1.488 | dead: conv=0.43 q=0.00
# epoch 17: tL=0.0450 vL=0.0428 lr=1.82e-04
#   push_x_pos   A=0.923 P=0.678 R=1.000 F1=0.808 M=0.262 S=0.274
#   push_x_neg   A=0.912 P=0.667 R=0.999 F1=0.800 M=0.275 S=0.278
#   push_y_pos   A=0.916 P=0.677 R=0.998 F1=0.806 M=0.279 S=0.275
#   push_y_neg   A=0.926 P=0.694 R=0.998 F1=0.818 M=0.267 S=0.266
#   lift_x       A=0.681 P=0.634 R=0.732 F1=0.679 M=0.500 S=0.083
#   lift_y       A=0.700 P=0.671 R=0.729 F1=0.699 M=0.498 S=0.094
#   pull_x       A=0.674 P=0.569 R=0.731 F1=0.640 M=0.496 S=0.085
#   pull_y       A=0.682 P=0.600 R=0.714 F1=0.652 M=0.493 S=0.095
# impacts: d=4.255 m=0.950 dist=1.267 q=1.014 | std: c1=0.136 c2=0.115 c3=0.154 c4=0.154 pool=0.118 quat=0.269 logit=1.594 | dead: conv=0.43 q=0.00
# epoch 18: tL=0.0444 vL=0.0427 lr=1.90e-04
#   push_x_pos   A=0.924 P=0.681 R=1.000 F1=0.810 M=0.250 S=0.276
#   push_x_neg   A=0.911 P=0.664 R=1.000 F1=0.798 M=0.274 S=0.284
#   push_y_pos   A=0.919 P=0.683 R=0.998 F1=0.811 M=0.261 S=0.271
#   push_y_neg   A=0.927 P=0.697 R=0.998 F1=0.820 M=0.263 S=0.273
#   lift_x       A=0.677 P=0.615 R=0.809 F1=0.699 M=0.513 S=0.078
#   lift_y       A=0.696 P=0.655 R=0.769 F1=0.707 M=0.506 S=0.085
#   pull_x       A=0.675 P=0.561 R=0.822 F1=0.667 M=0.507 S=0.081
#   pull_y       A=0.682 P=0.591 R=0.766 F1=0.667 M=0.500 S=0.088
# impacts: d=3.830 m=0.960 dist=1.322 q=1.067 | std: c1=0.135 c2=0.118 c3=0.146 c4=0.146 pool=0.110 quat=0.269 logit=1.662 | dead: conv=0.44 q=0.00
# epoch 19: tL=0.0439 vL=0.0420 lr=1.95e-04
#   push_x_pos   A=0.925 P=0.683 R=1.000 F1=0.812 M=0.247 S=0.280
#   push_x_neg   A=0.914 P=0.671 R=1.000 F1=0.803 M=0.268 S=0.285
#   push_y_pos   A=0.919 P=0.685 R=0.999 F1=0.812 M=0.268 S=0.281
#   push_y_neg   A=0.929 P=0.700 R=0.999 F1=0.823 M=0.250 S=0.275
#   lift_x       A=0.694 P=0.647 R=0.743 F1=0.692 M=0.499 S=0.088
#   lift_y       A=0.712 P=0.675 R=0.764 F1=0.717 M=0.504 S=0.097
#   pull_x       A=0.692 P=0.586 R=0.763 F1=0.663 M=0.496 S=0.091
#   pull_y       A=0.694 P=0.607 R=0.753 F1=0.672 M=0.498 S=0.098
# impacts: d=3.876 m=1.039 dist=1.396 q=1.078 | std: c1=0.134 c2=0.124 c3=0.149 c4=0.149 pool=0.112 quat=0.269 logit=1.718 | dead: conv=0.45 q=0.00
# epoch 20: tL=0.0436 vL=0.0419 lr=1.99e-04
#   push_x_pos   A=0.927 P=0.690 R=0.994 F1=0.815 M=0.229 S=0.272
#   push_x_neg   A=0.916 P=0.677 R=1.000 F1=0.808 M=0.251 S=0.282
#   push_y_pos   A=0.922 P=0.692 R=0.997 F1=0.817 M=0.243 S=0.277
#   push_y_neg   A=0.933 P=0.712 R=0.998 F1=0.831 M=0.240 S=0.268
#   lift_x       A=0.706 P=0.682 R=0.680 F1=0.681 M=0.482 S=0.090
#   lift_y       A=0.711 P=0.719 R=0.647 F1=0.681 M=0.476 S=0.099
#   pull_x       A=0.708 P=0.621 R=0.673 F1=0.646 M=0.475 S=0.093
#   pull_y       A=0.707 P=0.654 R=0.629 F1=0.641 M=0.469 S=0.100
# impacts: d=3.726 m=1.037 dist=1.479 q=1.147 | std: c1=0.133 c2=0.129 c3=0.146 c4=0.146 pool=0.108 quat=0.270 logit=1.844 | dead: conv=0.46 q=0.00
# epoch 21: tL=0.0431 vL=0.0421 lr=2.00e-04
#   push_x_pos   A=0.924 P=0.682 R=1.000 F1=0.811 M=0.246 S=0.282
#   push_x_neg   A=0.913 P=0.669 R=1.000 F1=0.802 M=0.248 S=0.285
#   push_y_pos   A=0.920 P=0.685 R=1.000 F1=0.813 M=0.255 S=0.279
#   push_y_neg   A=0.928 P=0.697 R=0.999 F1=0.821 M=0.240 S=0.274
#   lift_x       A=0.683 P=0.620 R=0.815 F1=0.704 M=0.513 S=0.080
#   lift_y       A=0.700 P=0.644 R=0.831 F1=0.725 M=0.518 S=0.087
#   pull_x       A=0.673 P=0.559 R=0.826 F1=0.667 M=0.509 S=0.083
#   pull_y       A=0.679 P=0.582 R=0.813 F1=0.679 M=0.511 S=0.089
# impacts: d=3.301 m=1.018 dist=1.448 q=1.127 | std: c1=0.132 c2=0.131 c3=0.136 c4=0.136 pool=0.099 quat=0.271 logit=1.796 | dead: conv=0.48 q=0.00
# epoch 22: tL=0.0427 vL=0.0419 lr=2.00e-04
#   push_x_pos   A=0.924 P=0.682 R=1.000 F1=0.811 M=0.239 S=0.286
#   push_x_neg   A=0.914 P=0.671 R=1.000 F1=0.803 M=0.247 S=0.291
#   push_y_pos   A=0.920 P=0.687 R=0.999 F1=0.814 M=0.247 S=0.284
#   push_y_neg   A=0.929 P=0.702 R=0.999 F1=0.825 M=0.234 S=0.276
#   lift_x       A=0.674 P=0.604 R=0.858 F1=0.709 M=0.526 S=0.086
#   lift_y       A=0.702 P=0.642 R=0.843 F1=0.729 M=0.523 S=0.094
#   pull_x       A=0.658 P=0.542 R=0.872 F1=0.669 M=0.521 S=0.090
#   pull_y       A=0.680 P=0.581 R=0.835 F1=0.685 M=0.516 S=0.097
# impacts: d=3.317 m=1.067 dist=1.509 q=1.213 | std: c1=0.132 c2=0.137 c3=0.132 c4=0.132 pool=0.095 quat=0.271 logit=1.907 | dead: conv=0.50 q=0.00
# epoch 23: tL=0.0427 vL=0.0421 lr=2.00e-04
#   push_x_pos   A=0.925 P=0.685 R=1.000 F1=0.813 M=0.228 S=0.277
#   push_x_neg   A=0.915 P=0.674 R=1.000 F1=0.805 M=0.240 S=0.285
#   push_y_pos   A=0.919 P=0.685 R=0.999 F1=0.812 M=0.247 S=0.285
#   push_y_neg   A=0.930 P=0.705 R=0.999 F1=0.826 M=0.238 S=0.277
#   lift_x       A=0.662 P=0.590 R=0.882 F1=0.707 M=0.533 S=0.086
#   lift_y       A=0.690 P=0.627 R=0.865 F1=0.727 M=0.528 S=0.093
#   pull_x       A=0.653 P=0.537 R=0.897 F1=0.672 M=0.525 S=0.091
#   pull_y       A=0.667 P=0.566 R=0.859 F1=0.683 M=0.521 S=0.098
# impacts: d=3.172 m=1.075 dist=1.506 q=1.246 | std: c1=0.130 c2=0.143 c3=0.135 c4=0.135 pool=0.095 quat=0.270 logit=1.939 | dead: conv=0.50 q=0.00
# epoch 24: tL=0.0422 vL=0.0405 lr=1.99e-04
#   push_x_pos   A=0.926 P=0.690 R=0.995 F1=0.815 M=0.226 S=0.280
#   push_x_neg   A=0.914 P=0.673 R=1.000 F1=0.805 M=0.245 S=0.289
#   push_y_pos   A=0.923 P=0.693 R=0.999 F1=0.819 M=0.232 S=0.281
#   push_y_neg   A=0.930 P=0.705 R=0.998 F1=0.826 M=0.238 S=0.275
#   lift_x       A=0.716 P=0.696 R=0.685 F1=0.691 M=0.482 S=0.094
#   lift_y       A=0.723 P=0.719 R=0.689 F1=0.703 M=0.484 S=0.100
#   pull_x       A=0.723 P=0.635 R=0.706 F1=0.669 M=0.477 S=0.099
#   pull_y       A=0.727 P=0.663 R=0.701 F1=0.681 M=0.479 S=0.104
# impacts: d=3.475 m=1.186 dist=1.656 q=1.234 | std: c1=0.129 c2=0.149 c3=0.145 c4=0.145 pool=0.103 quat=0.270 logit=1.930 | dead: conv=0.49 q=0.00
# epoch 25: tL=0.0418 vL=0.0410 lr=1.99e-04
#   push_x_pos   A=0.925 P=0.683 R=1.000 F1=0.812 M=0.225 S=0.291
#   push_x_neg   A=0.913 P=0.670 R=0.999 F1=0.802 M=0.251 S=0.299
#   push_y_pos   A=0.920 P=0.686 R=1.000 F1=0.814 M=0.249 S=0.291
#   push_y_neg   A=0.930 P=0.704 R=0.999 F1=0.826 M=0.225 S=0.282
#   lift_x       A=0.692 P=0.624 R=0.838 F1=0.716 M=0.520 S=0.096
#   lift_y       A=0.713 P=0.652 R=0.854 F1=0.739 M=0.526 S=0.104
#   pull_x       A=0.675 P=0.559 R=0.859 F1=0.677 M=0.516 S=0.101
#   pull_y       A=0.692 P=0.592 R=0.841 F1=0.695 M=0.516 S=0.107
# impacts: d=3.303 m=1.197 dist=1.801 q=1.278 | std: c1=0.131 c2=0.154 c3=0.140 c4=0.140 pool=0.098 quat=0.269 logit=1.996 | dead: conv=0.51 q=0.00
# epoch 26: tL=0.0415 vL=0.0398 lr=1.98e-04
#   push_x_pos   A=0.926 P=0.688 R=1.000 F1=0.815 M=0.218 S=0.283
#   push_x_neg   A=0.915 P=0.675 R=1.000 F1=0.806 M=0.240 S=0.289
#   push_y_pos   A=0.922 P=0.691 R=0.999 F1=0.817 M=0.241 S=0.287
#   push_y_neg   A=0.931 P=0.707 R=0.998 F1=0.828 M=0.227 S=0.282
#   lift_x       A=0.725 P=0.684 R=0.751 F1=0.716 M=0.494 S=0.100
#   lift_y       A=0.733 P=0.701 R=0.767 F1=0.732 M=0.500 S=0.110
#   pull_x       A=0.722 P=0.619 R=0.775 F1=0.688 M=0.487 S=0.107
#   pull_y       A=0.721 P=0.636 R=0.772 F1=0.698 M=0.494 S=0.114
# impacts: d=3.354 m=1.264 dist=1.796 q=1.272 | std: c1=0.129 c2=0.158 c3=0.144 c4=0.144 pool=0.099 quat=0.272 logit=2.014 | dead: conv=0.50 q=0.00
# epoch 27: tL=0.0413 vL=0.0397 lr=1.97e-04
#   push_x_pos   A=0.925 P=0.685 R=0.999 F1=0.813 M=0.228 S=0.286
#   push_x_neg   A=0.915 P=0.674 R=1.000 F1=0.805 M=0.238 S=0.294
#   push_y_pos   A=0.920 P=0.687 R=0.999 F1=0.814 M=0.240 S=0.290
#   push_y_neg   A=0.929 P=0.702 R=0.998 F1=0.824 M=0.225 S=0.281
#   lift_x       A=0.728 P=0.701 R=0.715 F1=0.708 M=0.486 S=0.100
#   lift_y       A=0.740 P=0.730 R=0.721 F1=0.726 M=0.488 S=0.108
#   pull_x       A=0.733 P=0.641 R=0.740 F1=0.687 M=0.481 S=0.104
#   pull_y       A=0.732 P=0.665 R=0.723 F1=0.692 M=0.482 S=0.111
# impacts: d=3.517 m=1.318 dist=1.830 q=1.306 | std: c1=0.130 c2=0.163 c3=0.148 c4=0.148 pool=0.101 quat=0.273 logit=2.028 | dead: conv=0.51 q=0.00
# epoch 28: tL=0.0411 vL=0.0415 lr=1.96e-04
#   push_x_pos   A=0.926 P=0.688 R=0.999 F1=0.815 M=0.214 S=0.291
#   push_x_neg   A=0.915 P=0.675 R=1.000 F1=0.806 M=0.236 S=0.298
#   push_y_pos   A=0.922 P=0.693 R=0.999 F1=0.818 M=0.230 S=0.292
#   push_y_neg   A=0.931 P=0.708 R=0.996 F1=0.828 M=0.220 S=0.288
#   lift_x       A=0.670 P=0.596 R=0.886 F1=0.713 M=0.539 S=0.108
#   lift_y       A=0.691 P=0.626 R=0.869 F1=0.728 M=0.535 S=0.115
#   pull_x       A=0.660 P=0.543 R=0.899 F1=0.677 M=0.528 S=0.117
#   pull_y       A=0.679 P=0.576 R=0.869 F1=0.693 M=0.524 S=0.122
# impacts: d=3.517 m=1.229 dist=1.999 q=1.439 | std: c1=0.128 c2=0.161 c3=0.142 c4=0.142 pool=0.096 quat=0.273 logit=2.285 | dead: conv=0.50 q=0.00
# epoch 29: tL=0.0408 vL=0.0393 lr=1.95e-04
#   push_x_pos   A=0.926 P=0.688 R=1.000 F1=0.815 M=0.219 S=0.288
#   push_x_neg   A=0.915 P=0.674 R=1.000 F1=0.805 M=0.231 S=0.295
#   push_y_pos   A=0.922 P=0.691 R=0.998 F1=0.817 M=0.231 S=0.290
#   push_y_neg   A=0.931 P=0.708 R=0.996 F1=0.828 M=0.221 S=0.283
#   lift_x       A=0.724 P=0.677 R=0.772 F1=0.721 M=0.498 S=0.105
#   lift_y       A=0.740 P=0.703 R=0.786 F1=0.742 M=0.504 S=0.112
#   pull_x       A=0.727 P=0.622 R=0.791 F1=0.696 M=0.489 S=0.111
#   pull_y       A=0.732 P=0.645 R=0.792 F1=0.711 M=0.496 S=0.116
# impacts: d=3.290 m=1.228 dist=2.039 q=1.346 | std: c1=0.127 c2=0.165 c3=0.138 c4=0.138 pool=0.091 quat=0.273 logit=2.077 | dead: conv=0.53 q=0.00
# epoch 30: tL=0.0405 vL=0.0394 lr=1.94e-04
#   push_x_pos   A=0.927 P=0.690 R=1.000 F1=0.817 M=0.206 S=0.281
#   push_x_neg   A=0.915 P=0.675 R=1.000 F1=0.806 M=0.230 S=0.294
#   push_y_pos   A=0.921 P=0.690 R=1.000 F1=0.816 M=0.229 S=0.291
#   push_y_neg   A=0.932 P=0.709 R=0.998 F1=0.829 M=0.217 S=0.282
#   lift_x       A=0.707 P=0.635 R=0.860 F1=0.731 M=0.524 S=0.103
#   lift_y       A=0.738 P=0.695 R=0.803 F1=0.745 M=0.509 S=0.113
#   pull_x       A=0.702 P=0.584 R=0.862 F1=0.696 M=0.510 S=0.111
#   pull_y       A=0.730 P=0.642 R=0.796 F1=0.711 M=0.497 S=0.117
# impacts: d=3.351 m=1.261 dist=2.141 q=1.391 | std: c1=0.126 c2=0.166 c3=0.142 c4=0.142 pool=0.094 quat=0.274 logit=2.177 | dead: conv=0.53 q=0.00
# epoch 31: tL=0.0403 vL=0.0391 lr=1.92e-04
#   push_x_pos   A=0.926 P=0.688 R=1.000 F1=0.815 M=0.212 S=0.286
#   push_x_neg   A=0.915 P=0.675 R=1.000 F1=0.806 M=0.235 S=0.297
#   push_y_pos   A=0.922 P=0.691 R=0.999 F1=0.817 M=0.224 S=0.287
#   push_y_neg   A=0.932 P=0.709 R=0.998 F1=0.829 M=0.218 S=0.282
#   lift_x       A=0.727 P=0.671 R=0.805 F1=0.732 M=0.507 S=0.104
#   lift_y       A=0.737 P=0.685 R=0.831 F1=0.751 M=0.519 S=0.112
#   pull_x       A=0.723 P=0.615 R=0.808 F1=0.698 M=0.495 S=0.111
#   pull_y       A=0.726 P=0.631 R=0.825 F1=0.715 M=0.506 S=0.118
# impacts: d=3.408 m=1.234 dist=2.167 q=1.435 | std: c1=0.128 c2=0.169 c3=0.141 c4=0.141 pool=0.091 quat=0.272 logit=2.203 | dead: conv=0.54 q=0.00
# epoch 32: tL=0.0400 vL=0.0390 lr=1.91e-04
#   push_x_pos   A=0.924 P=0.682 R=1.000 F1=0.811 M=0.213 S=0.284
#   push_x_neg   A=0.915 P=0.674 R=1.000 F1=0.805 M=0.234 S=0.295
#   push_y_pos   A=0.920 P=0.687 R=0.999 F1=0.814 M=0.226 S=0.288
#   push_y_neg   A=0.929 P=0.700 R=0.999 F1=0.823 M=0.217 S=0.281
#   lift_x       A=0.725 P=0.674 R=0.783 F1=0.725 M=0.504 S=0.100
#   lift_y       A=0.744 P=0.706 R=0.791 F1=0.746 M=0.509 S=0.110
#   pull_x       A=0.720 P=0.611 R=0.805 F1=0.695 M=0.498 S=0.105
#   pull_y       A=0.732 P=0.648 R=0.782 F1=0.708 M=0.497 S=0.114
# impacts: d=3.135 m=1.326 dist=2.229 q=1.421 | std: c1=0.128 c2=0.175 c3=0.140 c4=0.140 pool=0.089 quat=0.272 logit=2.191 | dead: conv=0.56 q=0.00
# epoch 33: tL=0.0397 vL=0.0384 lr=1.89e-04
#   push_x_pos   A=0.927 P=0.690 R=0.999 F1=0.816 M=0.208 S=0.295
#   push_x_neg   A=0.917 P=0.680 R=0.999 F1=0.809 M=0.230 S=0.302
#   push_y_pos   A=0.921 P=0.689 R=0.999 F1=0.816 M=0.229 S=0.301
#   push_y_neg   A=0.933 P=0.714 R=0.995 F1=0.831 M=0.206 S=0.288
#   lift_x       A=0.736 P=0.692 R=0.773 F1=0.731 M=0.497 S=0.117
#   lift_y       A=0.747 P=0.718 R=0.775 F1=0.745 M=0.500 S=0.128
#   pull_x       A=0.737 P=0.632 R=0.802 F1=0.707 M=0.489 S=0.125
#   pull_y       A=0.742 P=0.662 R=0.782 F1=0.717 M=0.489 S=0.133
# impacts: d=3.449 m=1.359 dist=2.523 q=1.510 | std: c1=0.129 c2=0.179 c3=0.148 c4=0.148 pool=0.094 quat=0.274 logit=2.351 | dead: conv=0.54 q=0.00
# epoch 34: tL=0.0396 vL=0.0393 lr=1.87e-04
#   push_x_pos   A=0.925 P=0.685 R=1.000 F1=0.813 M=0.209 S=0.291
#   push_x_neg   A=0.914 P=0.673 R=1.000 F1=0.805 M=0.226 S=0.300
#   push_y_pos   A=0.920 P=0.687 R=1.000 F1=0.814 M=0.221 S=0.295
#   push_y_neg   A=0.930 P=0.703 R=0.999 F1=0.825 M=0.218 S=0.288
#   lift_x       A=0.711 P=0.640 R=0.856 F1=0.733 M=0.526 S=0.108
#   lift_y       A=0.730 P=0.673 R=0.842 F1=0.748 M=0.528 S=0.116
#   pull_x       A=0.701 P=0.582 R=0.872 F1=0.698 M=0.514 S=0.115
#   pull_y       A=0.711 P=0.613 R=0.833 F1=0.706 M=0.514 S=0.121
# impacts: d=2.922 m=1.353 dist=2.549 q=1.529 | std: c1=0.129 c2=0.181 c3=0.142 c4=0.142 pool=0.088 quat=0.270 logit=2.326 | dead: conv=0.56 q=0.00
# epoch 35: tL=0.0394 vL=0.0383 lr=1.85e-04
#   push_x_pos   A=0.927 P=0.689 R=1.000 F1=0.816 M=0.203 S=0.291
#   push_x_neg   A=0.916 P=0.676 R=1.000 F1=0.807 M=0.234 S=0.301
#   push_y_pos   A=0.920 P=0.687 R=0.999 F1=0.814 M=0.223 S=0.296
#   push_y_neg   A=0.931 P=0.706 R=0.999 F1=0.827 M=0.217 S=0.289
#   lift_x       A=0.733 P=0.678 R=0.803 F1=0.736 M=0.506 S=0.111
#   lift_y       A=0.745 P=0.699 R=0.819 F1=0.754 M=0.518 S=0.125
#   pull_x       A=0.733 P=0.623 R=0.823 F1=0.709 M=0.497 S=0.118
#   pull_y       A=0.732 P=0.638 R=0.825 F1=0.720 M=0.507 S=0.130
# impacts: d=3.669 m=1.405 dist=2.557 q=1.500 | std: c1=0.127 c2=0.183 c3=0.147 c4=0.147 pool=0.091 quat=0.278 logit=2.348 | dead: conv=0.54 q=0.00
# epoch 36: tL=0.0388 vL=0.0379 lr=1.83e-04
#   push_x_pos   A=0.926 P=0.686 R=1.000 F1=0.814 M=0.211 S=0.295
#   push_x_neg   A=0.916 P=0.677 R=0.998 F1=0.807 M=0.223 S=0.301
#   push_y_pos   A=0.920 P=0.687 R=0.999 F1=0.814 M=0.225 S=0.298
#   push_y_neg   A=0.932 P=0.710 R=0.998 F1=0.830 M=0.206 S=0.286
#   lift_x       A=0.735 P=0.669 R=0.844 F1=0.747 M=0.518 S=0.117
#   lift_y       A=0.754 P=0.716 R=0.801 F1=0.756 M=0.510 S=0.132
#   pull_x       A=0.725 P=0.608 R=0.864 F1=0.713 M=0.509 S=0.124
#   pull_y       A=0.742 P=0.654 R=0.808 F1=0.723 M=0.499 S=0.136
# impacts: d=3.424 m=1.544 dist=2.778 q=1.505 | std: c1=0.130 c2=0.190 c3=0.152 c4=0.152 pool=0.094 quat=0.276 logit=2.306 | dead: conv=0.56 q=0.00
# epoch 37: tL=0.0389 vL=0.0376 lr=1.81e-04
#   push_x_pos   A=0.925 P=0.683 R=1.000 F1=0.812 M=0.207 S=0.292
#   push_x_neg   A=0.913 P=0.670 R=0.999 F1=0.802 M=0.230 S=0.302
#   push_y_pos   A=0.920 P=0.687 R=0.999 F1=0.814 M=0.221 S=0.295
#   push_y_neg   A=0.929 P=0.702 R=0.999 F1=0.824 M=0.214 S=0.288
#   lift_x       A=0.748 P=0.736 R=0.709 F1=0.722 M=0.483 S=0.114
#   lift_y       A=0.767 P=0.753 R=0.759 F1=0.756 M=0.495 S=0.125
#   pull_x       A=0.755 P=0.675 R=0.737 F1=0.704 M=0.476 S=0.119
#   pull_y       A=0.762 P=0.697 R=0.759 F1=0.727 M=0.485 S=0.129
# impacts: d=3.693 m=1.510 dist=2.686 q=1.484 | std: c1=0.128 c2=0.190 c3=0.152 c4=0.152 pool=0.092 quat=0.278 logit=2.312 | dead: conv=0.57 q=0.00
# epoch 38: tL=0.0388 vL=0.0375 lr=1.79e-04
#   push_x_pos   A=0.926 P=0.686 R=1.000 F1=0.814 M=0.209 S=0.296
#   push_x_neg   A=0.915 P=0.675 R=1.000 F1=0.806 M=0.228 S=0.305
#   push_y_pos   A=0.922 P=0.691 R=0.999 F1=0.817 M=0.213 S=0.294
#   push_y_neg   A=0.931 P=0.707 R=0.999 F1=0.828 M=0.215 S=0.292
#   lift_x       A=0.747 P=0.699 R=0.795 F1=0.744 M=0.504 S=0.116
#   lift_y       A=0.758 P=0.716 R=0.817 F1=0.763 M=0.513 S=0.129
#   pull_x       A=0.746 P=0.640 R=0.823 F1=0.720 M=0.493 S=0.123
#   pull_y       A=0.745 P=0.654 R=0.824 F1=0.729 M=0.504 S=0.133
# impacts: d=3.417 m=1.442 dist=2.705 q=1.547 | std: c1=0.129 c2=0.194 c3=0.152 c4=0.152 pool=0.092 quat=0.275 logit=2.397 | dead: conv=0.57 q=0.00
# epoch 39: tL=0.0384 vL=0.0383 lr=1.76e-04
#   push_x_pos   A=0.927 P=0.689 R=1.000 F1=0.816 M=0.200 S=0.294
#   push_x_neg   A=0.916 P=0.677 R=0.999 F1=0.807 M=0.222 S=0.301
#   push_y_pos   A=0.921 P=0.689 R=0.998 F1=0.815 M=0.216 S=0.299
#   push_y_neg   A=0.931 P=0.709 R=0.998 F1=0.829 M=0.209 S=0.294
#   lift_x       A=0.723 P=0.654 R=0.850 F1=0.739 M=0.524 S=0.121
#   lift_y       A=0.742 P=0.686 R=0.848 F1=0.758 M=0.526 S=0.134
#   pull_x       A=0.717 P=0.598 R=0.870 F1=0.709 M=0.513 S=0.130
#   pull_y       A=0.730 P=0.630 R=0.857 F1=0.726 M=0.515 S=0.139
# impacts: d=3.982 m=1.457 dist=2.671 q=1.621 | std: c1=0.128 c2=0.197 c3=0.152 c4=0.152 pool=0.091 quat=0.270 logit=2.444 | dead: conv=0.57 q=0.00
# epoch 40: tL=0.0382 vL=0.0370 lr=1.73e-04
#   push_x_pos   A=0.927 P=0.689 R=1.000 F1=0.816 M=0.199 S=0.293
#   push_x_neg   A=0.915 P=0.675 R=1.000 F1=0.806 M=0.224 S=0.305
#   push_y_pos   A=0.921 P=0.689 R=0.999 F1=0.815 M=0.216 S=0.299
#   push_y_neg   A=0.931 P=0.709 R=0.996 F1=0.828 M=0.206 S=0.289
#   lift_x       A=0.755 P=0.734 R=0.736 F1=0.735 M=0.486 S=0.128
#   lift_y       A=0.770 P=0.778 R=0.723 F1=0.750 M=0.479 S=0.136
#   pull_x       A=0.762 P=0.676 R=0.767 F1=0.719 M=0.475 S=0.134
#   pull_y       A=0.768 P=0.716 R=0.735 F1=0.725 M=0.471 S=0.140
# impacts: d=3.893 m=1.560 dist=2.832 q=1.583 | std: c1=0.129 c2=0.201 c3=0.159 c4=0.159 pool=0.094 quat=0.273 logit=2.425 | dead: conv=0.56 q=0.00
# epoch 41: tL=0.0379 vL=0.0374 lr=1.71e-04
#   push_x_pos   A=0.927 P=0.689 R=1.000 F1=0.816 M=0.204 S=0.297
#   push_x_neg   A=0.916 P=0.677 R=0.999 F1=0.807 M=0.228 S=0.308
#   push_y_pos   A=0.921 P=0.690 R=0.999 F1=0.816 M=0.214 S=0.299
#   push_y_neg   A=0.931 P=0.708 R=0.998 F1=0.828 M=0.211 S=0.295
#   lift_x       A=0.748 P=0.695 R=0.812 F1=0.749 M=0.507 S=0.125
#   lift_y       A=0.753 P=0.693 R=0.865 F1=0.770 M=0.531 S=0.139
#   pull_x       A=0.743 P=0.633 R=0.838 F1=0.721 M=0.498 S=0.132
#   pull_y       A=0.738 P=0.635 R=0.872 F1=0.735 M=0.520 S=0.143
# impacts: d=3.892 m=1.534 dist=2.932 q=1.551 | std: c1=0.129 c2=0.203 c3=0.156 c4=0.156 pool=0.092 quat=0.281 logit=2.501 | dead: conv=0.58 q=0.00
# epoch 42: tL=0.0376 vL=0.0365 lr=1.68e-04
#   push_x_pos   A=0.927 P=0.690 R=1.000 F1=0.817 M=0.200 S=0.292
#   push_x_neg   A=0.916 P=0.678 R=0.999 F1=0.808 M=0.217 S=0.303
#   push_y_pos   A=0.922 P=0.691 R=0.999 F1=0.817 M=0.215 S=0.298
#   push_y_neg   A=0.931 P=0.707 R=0.996 F1=0.827 M=0.204 S=0.291
#   lift_x       A=0.759 P=0.712 R=0.806 F1=0.756 M=0.503 S=0.128
#   lift_y       A=0.773 P=0.744 R=0.798 F1=0.770 M=0.503 S=0.144
#   pull_x       A=0.757 P=0.653 R=0.827 F1=0.730 M=0.492 S=0.134
#   pull_y       A=0.763 P=0.687 R=0.791 F1=0.735 M=0.490 S=0.146
# impacts: d=3.964 m=1.582 dist=2.927 q=1.687 | std: c1=0.130 c2=0.210 c3=0.161 c4=0.161 pool=0.094 quat=0.273 logit=2.521 | dead: conv=0.58 q=0.00
# epoch 43: tL=0.0374 vL=0.0373 lr=1.65e-04
#   push_x_pos   A=0.927 P=0.690 R=1.000 F1=0.817 M=0.197 S=0.298
#   push_x_neg   A=0.916 P=0.678 R=1.000 F1=0.808 M=0.216 S=0.304
#   push_y_pos   A=0.922 P=0.691 R=0.999 F1=0.817 M=0.210 S=0.304
#   push_y_neg   A=0.932 P=0.710 R=0.996 F1=0.829 M=0.205 S=0.295
#   lift_x       A=0.737 P=0.672 R=0.840 F1=0.747 M=0.518 S=0.137
#   lift_y       A=0.755 P=0.704 R=0.840 F1=0.766 M=0.522 S=0.148
#   pull_x       A=0.735 P=0.620 R=0.851 F1=0.718 M=0.503 S=0.145
#   pull_y       A=0.740 P=0.645 R=0.837 F1=0.729 M=0.508 S=0.153
# impacts: d=4.802 m=1.561 dist=2.994 q=1.680 | std: c1=0.131 c2=0.214 c3=0.161 c4=0.161 pool=0.095 quat=0.276 logit=2.675 | dead: conv=0.57 q=0.00
# epoch 44: tL=0.0374 vL=0.0368 lr=1.62e-04
#   push_x_pos   A=0.927 P=0.690 R=1.000 F1=0.817 M=0.195 S=0.293
#   push_x_neg   A=0.916 P=0.679 R=0.998 F1=0.808 M=0.218 S=0.305
#   push_y_pos   A=0.922 P=0.691 R=0.999 F1=0.817 M=0.209 S=0.299
#   push_y_neg   A=0.932 P=0.711 R=0.999 F1=0.831 M=0.205 S=0.293
#   lift_x       A=0.740 P=0.674 R=0.849 F1=0.751 M=0.521 S=0.134
#   lift_y       A=0.764 P=0.716 R=0.840 F1=0.773 M=0.518 S=0.144
#   pull_x       A=0.734 P=0.618 R=0.857 F1=0.718 M=0.506 S=0.140
#   pull_y       A=0.757 P=0.667 R=0.831 F1=0.740 M=0.500 S=0.147
# impacts: d=3.899 m=1.543 dist=2.929 q=1.646 | std: c1=0.127 c2=0.209 c3=0.159 c4=0.159 pool=0.091 quat=0.276 logit=2.598 | dead: conv=0.59 q=0.00
# epoch 45: tL=0.0372 vL=0.0373 lr=1.59e-04
#   push_x_pos   A=0.927 P=0.690 R=0.997 F1=0.816 M=0.199 S=0.299
#   push_x_neg   A=0.917 P=0.679 R=1.000 F1=0.809 M=0.217 S=0.310
#   push_y_pos   A=0.922 P=0.692 R=0.999 F1=0.818 M=0.208 S=0.302
#   push_y_neg   A=0.932 P=0.712 R=0.998 F1=0.831 M=0.205 S=0.296
#   lift_x       A=0.738 P=0.669 R=0.855 F1=0.751 M=0.523 S=0.138
#   lift_y       A=0.754 P=0.700 R=0.845 F1=0.766 M=0.523 S=0.149
#   pull_x       A=0.728 P=0.610 R=0.872 F1=0.717 M=0.510 S=0.146
#   pull_y       A=0.742 P=0.646 R=0.842 F1=0.731 M=0.508 S=0.154
# impacts: d=4.360 m=1.571 dist=3.133 q=1.768 | std: c1=0.132 c2=0.220 c3=0.166 c4=0.166 pool=0.096 quat=0.276 logit=2.763 | dead: conv=0.56 q=0.00
# epoch 46: tL=0.0369 vL=0.0359 lr=1.56e-04
#   push_x_pos   A=0.927 P=0.690 R=1.000 F1=0.817 M=0.198 S=0.294
#   push_x_neg   A=0.917 P=0.679 R=1.000 F1=0.809 M=0.217 S=0.305
#   push_y_pos   A=0.922 P=0.691 R=0.999 F1=0.817 M=0.214 S=0.300
#   push_y_neg   A=0.932 P=0.711 R=0.998 F1=0.830 M=0.199 S=0.288
#   lift_x       A=0.763 P=0.746 R=0.738 F1=0.742 M=0.482 S=0.132
#   lift_y       A=0.779 P=0.759 R=0.788 F1=0.773 M=0.497 S=0.148
#   pull_x       A=0.770 P=0.691 R=0.759 F1=0.723 M=0.470 S=0.138
#   pull_y       A=0.775 P=0.706 R=0.788 F1=0.745 M=0.482 S=0.151
# impacts: d=4.311 m=1.607 dist=3.034 q=1.687 | std: c1=0.129 c2=0.218 c3=0.165 c4=0.165 pool=0.093 quat=0.278 logit=2.600 | dead: conv=0.59 q=0.00
# epoch 47: tL=0.0368 vL=0.0362 lr=1.52e-04
#   push_x_pos   A=0.927 P=0.689 R=1.000 F1=0.816 M=0.196 S=0.296
#   push_x_neg   A=0.916 P=0.678 R=1.000 F1=0.808 M=0.215 S=0.306
#   push_y_pos   A=0.922 P=0.692 R=0.999 F1=0.817 M=0.208 S=0.301
#   push_y_neg   A=0.932 P=0.710 R=0.999 F1=0.830 M=0.200 S=0.295
#   lift_x       A=0.756 P=0.701 R=0.826 F1=0.758 M=0.509 S=0.135
#   lift_y       A=0.772 P=0.725 R=0.840 F1=0.778 M=0.516 S=0.148
#   pull_x       A=0.752 P=0.644 R=0.839 F1=0.729 M=0.494 S=0.142
#   pull_y       A=0.758 P=0.666 R=0.842 F1=0.744 M=0.502 S=0.152
# impacts: d=4.705 m=1.630 dist=3.029 q=1.795 | std: c1=0.131 c2=0.223 c3=0.166 c4=0.166 pool=0.094 quat=0.275 logit=2.724 | dead: conv=0.61 q=0.00
# epoch 48: tL=0.0366 vL=0.0358 lr=1.49e-04
#   push_x_pos   A=0.927 P=0.689 R=1.000 F1=0.816 M=0.199 S=0.296
#   push_x_neg   A=0.916 P=0.677 R=0.999 F1=0.807 M=0.220 S=0.309
#   push_y_pos   A=0.922 P=0.692 R=0.999 F1=0.817 M=0.207 S=0.300
#   push_y_neg   A=0.932 P=0.710 R=0.999 F1=0.830 M=0.201 S=0.293
#   lift_x       A=0.762 P=0.707 R=0.829 F1=0.763 M=0.506 S=0.137
#   lift_y       A=0.776 P=0.732 R=0.836 F1=0.780 M=0.513 S=0.148
#   pull_x       A=0.756 P=0.648 R=0.843 F1=0.733 M=0.494 S=0.143
#   pull_y       A=0.767 P=0.679 R=0.836 F1=0.749 M=0.498 S=0.151
# impacts: d=4.392 m=1.558 dist=2.899 q=1.707 | std: c1=0.131 c2=0.225 c3=0.168 c4=0.168 pool=0.094 quat=0.273 logit=2.630 | dead: conv=0.60 q=0.00
# epoch 49: tL=0.0364 vL=0.0358 lr=1.45e-04
#   push_x_pos   A=0.927 P=0.690 R=1.000 F1=0.817 M=0.195 S=0.295
#   push_x_neg   A=0.915 P=0.676 R=0.999 F1=0.806 M=0.218 S=0.308
#   push_y_pos   A=0.922 P=0.691 R=0.999 F1=0.817 M=0.205 S=0.301
#   push_y_neg   A=0.933 P=0.712 R=0.999 F1=0.831 M=0.203 S=0.295
#   lift_x       A=0.763 P=0.773 R=0.689 F1=0.729 M=0.466 S=0.142
#   lift_y       A=0.783 P=0.786 R=0.749 F1=0.767 M=0.481 S=0.152
#   pull_x       A=0.773 P=0.711 R=0.720 F1=0.715 M=0.456 S=0.146
#   pull_y       A=0.781 P=0.729 R=0.753 F1=0.741 M=0.470 S=0.154
# impacts: d=4.855 m=1.711 dist=3.317 q=1.773 | std: c1=0.130 c2=0.225 c3=0.171 c4=0.171 pool=0.097 quat=0.275 logit=2.668 | dead: conv=0.60 q=0.00
# epoch 50: tL=0.0362 vL=0.0358 lr=1.42e-04
#   push_x_pos   A=0.927 P=0.689 R=1.000 F1=0.816 M=0.198 S=0.297
#   push_x_neg   A=0.915 P=0.676 R=0.998 F1=0.806 M=0.214 S=0.305
#   push_y_pos   A=0.922 P=0.693 R=0.999 F1=0.818 M=0.209 S=0.301
#   push_y_neg   A=0.932 P=0.711 R=0.999 F1=0.831 M=0.202 S=0.292
#   lift_x       A=0.763 P=0.709 R=0.825 F1=0.763 M=0.510 S=0.138
#   lift_y       A=0.772 P=0.726 R=0.839 F1=0.778 M=0.517 S=0.147
#   pull_x       A=0.755 P=0.645 R=0.849 F1=0.733 M=0.499 S=0.143
#   pull_y       A=0.757 P=0.664 R=0.844 F1=0.743 M=0.503 S=0.150
# impacts: d=4.723 m=1.668 dist=3.232 q=1.699 | std: c1=0.130 c2=0.228 c3=0.170 c4=0.170 pool=0.096 quat=0.276 logit=2.601 | dead: conv=0.60 q=0.00
# epoch 51: tL=0.0359 vL=0.0351 lr=1.38e-04
#   push_x_pos   A=0.927 P=0.691 R=1.000 F1=0.817 M=0.193 S=0.295
#   push_x_neg   A=0.916 P=0.677 R=0.999 F1=0.807 M=0.214 S=0.307
#   push_y_pos   A=0.921 P=0.690 R=0.999 F1=0.816 M=0.206 S=0.300
#   push_y_neg   A=0.932 P=0.711 R=0.999 F1=0.831 M=0.197 S=0.294
#   lift_x       A=0.775 P=0.753 R=0.764 F1=0.758 M=0.485 S=0.143
#   lift_y       A=0.792 P=0.795 R=0.761 F1=0.777 M=0.481 S=0.156
#   pull_x       A=0.783 P=0.703 R=0.785 F1=0.742 M=0.470 S=0.149
#   pull_y       A=0.786 P=0.735 R=0.760 F1=0.747 M=0.468 S=0.158
# impacts: d=4.731 m=1.610 dist=3.155 q=1.720 | std: c1=0.131 c2=0.231 c3=0.176 c4=0.176 pool=0.098 quat=0.279 logit=2.665 | dead: conv=0.59 q=0.00
# epoch 52: tL=0.0359 vL=0.0352 lr=1.35e-04
#   push_x_pos   A=0.927 P=0.691 R=1.000 F1=0.817 M=0.193 S=0.297
#   push_x_neg   A=0.916 P=0.678 R=1.000 F1=0.808 M=0.216 S=0.309
#   push_y_pos   A=0.922 P=0.693 R=0.999 F1=0.818 M=0.204 S=0.299
#   push_y_neg   A=0.932 P=0.710 R=0.999 F1=0.830 M=0.202 S=0.296
#   lift_x       A=0.769 P=0.721 R=0.817 F1=0.766 M=0.504 S=0.141
#   lift_y       A=0.781 P=0.749 R=0.813 F1=0.780 M=0.505 S=0.151
#   pull_x       A=0.765 P=0.659 R=0.842 F1=0.739 M=0.491 S=0.146
#   pull_y       A=0.777 P=0.699 R=0.815 F1=0.753 M=0.491 S=0.153
# impacts: d=5.230 m=1.636 dist=3.182 q=1.783 | std: c1=0.133 c2=0.237 c3=0.174 c4=0.174 pool=0.097 quat=0.279 logit=2.789 | dead: conv=0.60 q=0.00
# epoch 53: tL=0.0357 vL=0.0349 lr=1.31e-04
#   push_x_pos   A=0.927 P=0.691 R=1.000 F1=0.817 M=0.190 S=0.297
#   push_x_neg   A=0.916 P=0.678 R=1.000 F1=0.808 M=0.218 S=0.310
#   push_y_pos   A=0.922 P=0.692 R=0.999 F1=0.818 M=0.206 S=0.302
#   push_y_neg   A=0.933 P=0.713 R=0.999 F1=0.832 M=0.197 S=0.294
#   lift_x       A=0.772 P=0.748 R=0.765 F1=0.756 M=0.484 S=0.147
#   lift_y       A=0.790 P=0.771 R=0.796 F1=0.784 M=0.495 S=0.159
#   pull_x       A=0.779 P=0.694 R=0.792 F1=0.740 M=0.471 S=0.152
#   pull_y       A=0.785 P=0.717 R=0.800 F1=0.757 M=0.482 S=0.161
# impacts: d=5.227 m=1.834 dist=3.342 q=1.837 | std: c1=0.136 c2=0.245 c3=0.179 c4=0.179 pool=0.100 quat=0.279 logit=2.841 | dead: conv=0.60 q=0.00
# epoch 54: tL=0.0354 vL=0.0349 lr=1.27e-04
#   push_x_pos   A=0.927 P=0.690 R=1.000 F1=0.817 M=0.195 S=0.298
#   push_x_neg   A=0.917 P=0.679 R=0.999 F1=0.809 M=0.212 S=0.305
#   push_y_pos   A=0.922 P=0.691 R=1.000 F1=0.817 M=0.207 S=0.302
#   push_y_neg   A=0.933 P=0.713 R=0.999 F1=0.832 M=0.196 S=0.295
#   lift_x       A=0.770 P=0.727 R=0.805 F1=0.764 M=0.500 S=0.145
#   lift_y       A=0.787 P=0.752 R=0.823 F1=0.786 M=0.505 S=0.156
#   pull_x       A=0.768 P=0.666 R=0.833 F1=0.740 M=0.488 S=0.150
#   pull_y       A=0.785 P=0.707 R=0.827 F1=0.762 M=0.490 S=0.158
# impacts: d=5.357 m=1.788 dist=3.343 q=1.811 | std: c1=0.134 c2=0.244 c3=0.181 c4=0.181 pool=0.101 quat=0.278 logit=2.770 | dead: conv=0.59 q=0.00
# epoch 55: tL=0.0354 vL=0.0349 lr=1.23e-04
#   push_x_pos   A=0.927 P=0.691 R=1.000 F1=0.817 M=0.193 S=0.298
#   push_x_neg   A=0.916 P=0.679 R=0.998 F1=0.808 M=0.211 S=0.306
#   push_y_pos   A=0.923 P=0.693 R=0.999 F1=0.819 M=0.203 S=0.302
#   push_y_neg   A=0.933 P=0.713 R=0.999 F1=0.832 M=0.200 S=0.296
#   lift_x       A=0.773 P=0.744 R=0.776 F1=0.760 M=0.486 S=0.148
#   lift_y       A=0.789 P=0.781 R=0.773 F1=0.777 M=0.484 S=0.157
#   pull_x       A=0.777 P=0.688 R=0.799 F1=0.739 M=0.472 S=0.153
#   pull_y       A=0.788 P=0.730 R=0.780 F1=0.754 M=0.472 S=0.159
# impacts: d=5.372 m=1.867 dist=3.415 q=1.873 | std: c1=0.136 c2=0.249 c3=0.183 c4=0.183 pool=0.101 quat=0.276 logit=2.812 | dead: conv=0.60 q=0.00
# epoch 56: tL=0.0353 vL=0.0348 lr=1.19e-04
#   push_x_pos   A=0.927 P=0.691 R=1.000 F1=0.817 M=0.191 S=0.297
#   push_x_neg   A=0.915 P=0.676 R=0.998 F1=0.806 M=0.211 S=0.309
#   push_y_pos   A=0.923 P=0.694 R=0.999 F1=0.819 M=0.201 S=0.301
#   push_y_neg   A=0.932 P=0.711 R=0.999 F1=0.831 M=0.199 S=0.297
#   lift_x       A=0.773 P=0.749 R=0.764 F1=0.757 M=0.483 S=0.149
#   lift_y       A=0.793 P=0.776 R=0.796 F1=0.786 M=0.491 S=0.159
#   pull_x       A=0.778 P=0.695 R=0.786 F1=0.738 M=0.469 S=0.153
#   pull_y       A=0.785 P=0.719 R=0.792 F1=0.754 M=0.477 S=0.160
# impacts: d=5.047 m=1.747 dist=3.518 q=1.877 | std: c1=0.136 c2=0.248 c3=0.181 c4=0.181 pool=0.100 quat=0.279 logit=2.846 | dead: conv=0.60 q=0.00
# epoch 57: tL=0.0351 vL=0.0346 lr=1.16e-04
#   push_x_pos   A=0.927 P=0.691 R=1.000 F1=0.817 M=0.193 S=0.302
#   push_x_neg   A=0.916 P=0.677 R=0.999 F1=0.807 M=0.216 S=0.315
#   push_y_pos   A=0.921 P=0.689 R=0.999 F1=0.816 M=0.208 S=0.308
#   push_y_neg   A=0.933 P=0.712 R=0.999 F1=0.831 M=0.199 S=0.301
#   lift_x       A=0.777 P=0.744 R=0.789 F1=0.766 M=0.494 S=0.154
#   lift_y       A=0.793 P=0.763 R=0.819 F1=0.790 M=0.505 S=0.164
#   pull_x       A=0.778 P=0.683 R=0.818 F1=0.745 M=0.482 S=0.158
#   pull_y       A=0.788 P=0.712 R=0.826 F1=0.764 M=0.490 S=0.166
# impacts: d=5.483 m=1.919 dist=3.534 q=1.829 | std: c1=0.139 c2=0.258 c3=0.188 c4=0.188 pool=0.104 quat=0.284 logit=2.891 | dead: conv=0.60 q=0.00
# epoch 58: tL=0.0350 vL=0.0346 lr=1.12e-04
#   push_x_pos   A=0.927 P=0.690 R=1.000 F1=0.817 M=0.191 S=0.297
#   push_x_neg   A=0.916 P=0.677 R=1.000 F1=0.808 M=0.215 S=0.308
#   push_y_pos   A=0.922 P=0.692 R=0.999 F1=0.817 M=0.206 S=0.301
#   push_y_neg   A=0.933 P=0.712 R=0.999 F1=0.831 M=0.195 S=0.294
#   lift_x       A=0.778 P=0.741 R=0.798 F1=0.769 M=0.491 S=0.150
#   lift_y       A=0.789 P=0.752 R=0.831 F1=0.790 M=0.507 S=0.160
#   pull_x       A=0.780 P=0.686 R=0.819 F1=0.746 M=0.478 S=0.154
#   pull_y       A=0.782 P=0.700 R=0.833 F1=0.761 M=0.492 S=0.162
# impacts: d=5.449 m=1.862 dist=3.698 q=1.788 | std: c1=0.139 c2=0.258 c3=0.186 c4=0.186 pool=0.102 quat=0.277 logit=2.742 | dead: conv=0.60 q=0.00
# epoch 59: tL=0.0348 vL=0.0351 lr=1.08e-04
#   push_x_pos   A=0.927 P=0.689 R=1.000 F1=0.816 M=0.195 S=0.300
#   push_x_neg   A=0.916 P=0.677 R=0.998 F1=0.807 M=0.211 S=0.309
#   push_y_pos   A=0.921 P=0.690 R=0.999 F1=0.816 M=0.207 S=0.300
#   push_y_neg   A=0.932 P=0.711 R=0.999 F1=0.831 M=0.195 S=0.294
#   lift_x       A=0.768 P=0.714 R=0.832 F1=0.769 M=0.508 S=0.146
#   lift_y       A=0.781 P=0.731 R=0.854 F1=0.788 M=0.520 S=0.157
#   pull_x       A=0.761 P=0.652 R=0.850 F1=0.738 M=0.495 S=0.151
#   pull_y       A=0.765 P=0.672 R=0.855 F1=0.752 M=0.504 S=0.159
# impacts: d=4.730 m=1.670 dist=3.848 q=1.831 | std: c1=0.136 c2=0.254 c3=0.182 c4=0.182 pool=0.099 quat=0.276 logit=2.854 | dead: conv=0.61 q=0.00
# epoch 60: tL=0.0347 vL=0.0346 lr=1.04e-04
#   push_x_pos   A=0.927 P=0.691 R=1.000 F1=0.817 M=0.191 S=0.301
#   push_x_neg   A=0.917 P=0.679 R=0.999 F1=0.809 M=0.211 S=0.310
#   push_y_pos   A=0.922 P=0.692 R=0.999 F1=0.817 M=0.204 S=0.305
#   push_y_neg   A=0.933 P=0.715 R=0.999 F1=0.833 M=0.192 S=0.297
#   lift_x       A=0.773 P=0.721 R=0.829 F1=0.771 M=0.505 S=0.155
#   lift_y       A=0.789 P=0.752 R=0.833 F1=0.790 M=0.506 S=0.164
#   pull_x       A=0.766 P=0.660 R=0.846 F1=0.741 M=0.490 S=0.160
#   pull_y       A=0.779 P=0.696 R=0.835 F1=0.759 M=0.492 S=0.167
# impacts: d=5.667 m=1.781 dist=3.968 q=1.946 | std: c1=0.139 c2=0.260 c3=0.188 c4=0.188 pool=0.103 quat=0.280 logit=2.991 | dead: conv=0.60 q=0.00
# epoch 61: tL=0.0346 vL=0.0346 lr=1.00e-04
#   push_x_pos   A=0.928 P=0.693 R=1.000 F1=0.819 M=0.189 S=0.298
#   push_x_neg   A=0.917 P=0.681 R=0.998 F1=0.810 M=0.205 S=0.309
#   push_y_pos   A=0.925 P=0.698 R=0.999 F1=0.822 M=0.199 S=0.302
#   push_y_neg   A=0.933 P=0.715 R=0.999 F1=0.833 M=0.190 S=0.297
#   lift_x       A=0.773 P=0.726 R=0.816 F1=0.768 M=0.500 S=0.156
#   lift_y       A=0.787 P=0.748 R=0.834 F1=0.788 M=0.509 S=0.167
#   pull_x       A=0.772 P=0.668 R=0.845 F1=0.746 M=0.486 S=0.161
#   pull_y       A=0.780 P=0.697 R=0.835 F1=0.759 M=0.493 S=0.169
# impacts: d=5.925 m=1.822 dist=4.227 q=2.042 | std: c1=0.136 c2=0.255 c3=0.185 c4=0.185 pool=0.101 quat=0.276 logit=3.144 | dead: conv=0.60 q=0.00
# epoch 62: tL=0.0345 vL=0.0343 lr=9.60e-05
#   push_x_pos   A=0.928 P=0.692 R=1.000 F1=0.818 M=0.192 S=0.300
#   push_x_neg   A=0.917 P=0.681 R=0.998 F1=0.810 M=0.206 S=0.308
#   push_y_pos   A=0.923 P=0.696 R=0.998 F1=0.820 M=0.199 S=0.302
#   push_y_neg   A=0.934 P=0.716 R=0.999 F1=0.834 M=0.190 S=0.294
#   lift_x       A=0.777 P=0.733 R=0.812 F1=0.771 M=0.498 S=0.154
#   lift_y       A=0.793 P=0.765 R=0.816 F1=0.790 M=0.500 S=0.164
#   pull_x       A=0.777 P=0.675 R=0.841 F1=0.749 M=0.485 S=0.159
#   pull_y       A=0.783 P=0.708 R=0.815 F1=0.758 M=0.484 S=0.166
# impacts: d=6.500 m=1.848 dist=4.275 q=1.924 | std: c1=0.139 c2=0.264 c3=0.192 c4=0.192 pool=0.105 quat=0.283 logit=3.065 | dead: conv=0.60 q=0.00
# epoch 63: tL=0.0343 vL=0.0350 lr=9.21e-05
#   push_x_pos   A=0.927 P=0.691 R=1.000 F1=0.817 M=0.192 S=0.304
#   push_x_neg   A=0.917 P=0.679 R=0.999 F1=0.809 M=0.208 S=0.311
#   push_y_pos   A=0.923 P=0.693 R=0.999 F1=0.819 M=0.202 S=0.305
#   push_y_neg   A=0.933 P=0.712 R=0.999 F1=0.831 M=0.196 S=0.300
#   lift_x       A=0.764 P=0.700 R=0.856 F1=0.770 M=0.518 S=0.154
#   lift_y       A=0.783 P=0.733 R=0.854 F1=0.789 M=0.521 S=0.163
#   pull_x       A=0.756 P=0.641 R=0.872 F1=0.739 M=0.503 S=0.159
#   pull_y       A=0.771 P=0.679 R=0.856 F1=0.757 M=0.506 S=0.166
# impacts: d=5.168 m=1.872 dist=4.262 q=1.937 | std: c1=0.140 c2=0.265 c3=0.191 c4=0.191 pool=0.104 quat=0.278 logit=2.984 | dead: conv=0.61 q=0.00
# epoch 64: tL=0.0343 vL=0.0340 lr=8.82e-05
#   push_x_pos   A=0.927 P=0.691 R=1.000 F1=0.817 M=0.192 S=0.302
#   push_x_neg   A=0.916 P=0.679 R=0.999 F1=0.808 M=0.211 S=0.314
#   push_y_pos   A=0.923 P=0.694 R=0.999 F1=0.819 M=0.204 S=0.306
#   push_y_neg   A=0.934 P=0.715 R=0.999 F1=0.834 M=0.194 S=0.298
#   lift_x       A=0.784 P=0.752 R=0.794 F1=0.773 M=0.491 S=0.160
#   lift_y       A=0.800 P=0.788 R=0.793 F1=0.791 M=0.490 S=0.169
#   pull_x       A=0.786 P=0.695 R=0.818 F1=0.751 M=0.477 S=0.164
#   pull_y       A=0.794 P=0.733 R=0.794 F1=0.763 M=0.475 S=0.170
# impacts: d=5.959 m=1.927 dist=4.476 q=1.939 | std: c1=0.142 c2=0.271 c3=0.196 c4=0.196 pool=0.107 quat=0.280 logit=3.001 | dead: conv=0.61 q=0.00
# epoch 65: tL=0.0342 vL=0.0340 lr=8.43e-05
#   push_x_pos   A=0.928 P=0.692 R=1.000 F1=0.818 M=0.189 S=0.300
#   push_x_neg   A=0.918 P=0.684 R=0.999 F1=0.812 M=0.207 S=0.310
#   push_y_pos   A=0.924 P=0.696 R=0.999 F1=0.820 M=0.201 S=0.304
#   push_y_neg   A=0.934 P=0.716 R=0.999 F1=0.834 M=0.188 S=0.296
#   lift_x       A=0.784 P=0.753 R=0.791 F1=0.772 M=0.488 S=0.161
#   lift_y       A=0.795 P=0.771 R=0.809 F1=0.790 M=0.496 S=0.172
#   pull_x       A=0.785 P=0.696 R=0.809 F1=0.749 M=0.471 S=0.166
#   pull_y       A=0.787 P=0.716 R=0.810 F1=0.760 M=0.479 S=0.174
# impacts: d=6.613 m=1.813 dist=4.452 q=1.957 | std: c1=0.140 c2=0.269 c3=0.195 c4=0.195 pool=0.106 quat=0.284 logit=3.056 | dead: conv=0.60 q=0.00
# epoch 66: tL=0.0339 vL=0.0342 lr=8.05e-05
#   push_x_pos   A=0.927 P=0.691 R=1.000 F1=0.817 M=0.190 S=0.302
#   push_x_neg   A=0.916 P=0.678 R=0.998 F1=0.808 M=0.210 S=0.314
#   push_y_pos   A=0.922 P=0.693 R=0.999 F1=0.818 M=0.204 S=0.308
#   push_y_neg   A=0.933 P=0.713 R=0.999 F1=0.832 M=0.192 S=0.299
#   lift_x       A=0.780 P=0.735 R=0.822 F1=0.776 M=0.500 S=0.161
#   lift_y       A=0.796 P=0.766 R=0.822 F1=0.793 M=0.503 S=0.170
#   pull_x       A=0.779 P=0.677 R=0.846 F1=0.752 M=0.485 S=0.165
#   pull_y       A=0.783 P=0.706 R=0.820 F1=0.759 M=0.487 S=0.172
# impacts: d=6.878 m=1.920 dist=4.735 q=2.031 | std: c1=0.141 c2=0.269 c3=0.194 c4=0.194 pool=0.106 quat=0.273 logit=3.060 | dead: conv=0.61 q=0.00
# epoch 67: tL=0.0340 vL=0.0342 lr=7.66e-05
#   push_x_pos   A=0.927 P=0.691 R=1.000 F1=0.817 M=0.189 S=0.300
#   push_x_neg   A=0.916 P=0.678 R=0.998 F1=0.807 M=0.210 S=0.312
#   push_y_pos   A=0.922 P=0.691 R=0.999 F1=0.817 M=0.203 S=0.307
#   push_y_neg   A=0.932 P=0.711 R=0.999 F1=0.831 M=0.194 S=0.301
#   lift_x       A=0.778 P=0.726 R=0.834 F1=0.776 M=0.506 S=0.159
#   lift_y       A=0.792 P=0.755 R=0.833 F1=0.792 M=0.507 S=0.167
#   pull_x       A=0.775 P=0.669 R=0.854 F1=0.751 M=0.490 S=0.164
#   pull_y       A=0.786 P=0.706 R=0.835 F1=0.765 M=0.492 S=0.168
# impacts: d=5.895 m=1.912 dist=4.855 q=1.975 | std: c1=0.142 c2=0.273 c3=0.197 c4=0.197 pool=0.107 quat=0.278 logit=3.027 | dead: conv=0.61 q=0.00
# epoch 68: tL=0.0339 vL=0.0344 lr=7.28e-05
#   push_x_pos   A=0.927 P=0.691 R=1.000 F1=0.817 M=0.188 S=0.302
#   push_x_neg   A=0.916 P=0.677 R=0.998 F1=0.807 M=0.210 S=0.314
#   push_y_pos   A=0.922 P=0.692 R=0.999 F1=0.817 M=0.201 S=0.306
#   push_y_neg   A=0.933 P=0.712 R=0.999 F1=0.831 M=0.193 S=0.300
#   lift_x       A=0.773 P=0.718 R=0.839 F1=0.774 M=0.509 S=0.159
#   lift_y       A=0.787 P=0.747 R=0.837 F1=0.790 M=0.510 S=0.168
#   pull_x       A=0.768 P=0.660 R=0.857 F1=0.746 M=0.494 S=0.164
#   pull_y       A=0.779 P=0.697 R=0.833 F1=0.759 M=0.493 S=0.170
# impacts: d=6.484 m=1.864 dist=4.824 q=2.024 | std: c1=0.143 c2=0.275 c3=0.198 c4=0.198 pool=0.108 quat=0.279 logit=3.157 | dead: conv=0.60 q=0.00
# epoch 69: tL=0.0338 vL=0.0338 lr=6.91e-05
#   push_x_pos   A=0.927 P=0.691 R=1.000 F1=0.817 M=0.189 S=0.300
#   push_x_neg   A=0.916 P=0.678 R=0.998 F1=0.808 M=0.207 S=0.310
#   push_y_pos   A=0.921 P=0.689 R=0.999 F1=0.815 M=0.204 S=0.307
# ...
#   push_x_neg   A=0.917 P=0.679 R=0.999 F1=0.809 M=0.205 S=0.310
#   push_y_pos   A=0.923 P=0.693 R=0.999 F1=0.819 M=0.200 S=0.305
#   push_y_neg   A=0.933 P=0.715 R=0.999 F1=0.833 M=0.189 S=0.297
#   lift_x       A=0.790 P=0.754 R=0.811 F1=0.781 M=0.491 S=0.166
#   lift_y       A=0.802 P=0.773 R=0.830 F1=0.800 M=0.501 S=0.175
#   pull_x       A=0.791 P=0.699 R=0.831 F1=0.759 M=0.475 S=0.170
#   pull_y       A=0.795 P=0.722 R=0.824 F1=0.770 M=0.483 S=0.176
# impacts: d=7.277 m=1.981 dist=5.633 q=2.006 | std: c1=0.146 c2=0.288 c3=0.205 c4=0.205 pool=0.111 quat=0.282 logit=3.133 | dead: conv=0.60 q=0.00
# epoch 79: tL=0.0331 vL=0.0333 lr=3.50e-05
#   push_x_pos   A=0.927 P=0.692 R=0.999 F1=0.817 M=0.186 S=0.300
#   push_x_neg   A=0.917 P=0.680 R=0.999 F1=0.809 M=0.206 S=0.311
#   push_y_pos   A=0.923 P=0.694 R=0.999 F1=0.819 M=0.201 S=0.305
#   push_y_neg   A=0.933 P=0.715 R=0.999 F1=0.833 M=0.189 S=0.298
#   lift_x       A=0.789 P=0.758 R=0.799 F1=0.778 M=0.487 S=0.168
#   lift_y       A=0.806 P=0.783 R=0.820 F1=0.801 M=0.496 S=0.177
#   pull_x       A=0.790 P=0.702 R=0.818 F1=0.756 M=0.471 S=0.172
#   pull_y       A=0.799 P=0.730 R=0.820 F1=0.773 M=0.479 S=0.178
# impacts: d=7.504 m=2.059 dist=5.629 q=2.090 | std: c1=0.149 c2=0.294 c3=0.210 c4=0.210 pool=0.114 quat=0.276 logit=3.125 | dead: conv=0.60 q=0.00
# epoch 80: tL=0.0329 vL=0.0335 lr=3.21e-05
#   push_x_pos   A=0.927 P=0.691 R=1.000 F1=0.817 M=0.186 S=0.302
#   push_x_neg   A=0.916 P=0.679 R=0.999 F1=0.808 M=0.207 S=0.314
#   push_y_pos   A=0.923 P=0.693 R=0.999 F1=0.819 M=0.199 S=0.307
#   push_y_neg   A=0.933 P=0.714 R=0.999 F1=0.833 M=0.190 S=0.300
#   lift_x       A=0.786 P=0.744 R=0.818 F1=0.779 M=0.495 S=0.168
#   lift_y       A=0.800 P=0.765 R=0.837 F1=0.799 M=0.504 S=0.176
#   pull_x       A=0.785 P=0.685 R=0.843 F1=0.756 M=0.479 S=0.172
#   pull_y       A=0.793 P=0.716 R=0.835 F1=0.771 M=0.487 S=0.178
# impacts: d=7.011 m=1.976 dist=5.596 q=2.081 | std: c1=0.148 c2=0.292 c3=0.209 c4=0.209 pool=0.113 quat=0.280 logit=3.180 | dead: conv=0.60 q=0.00
# epoch 81: tL=0.0329 vL=0.0340 lr=2.93e-05
#   push_x_pos   A=0.927 P=0.691 R=1.000 F1=0.817 M=0.187 S=0.303
#   push_x_neg   A=0.916 P=0.679 R=0.999 F1=0.808 M=0.208 S=0.315
#   push_y_pos   A=0.922 P=0.692 R=0.999 F1=0.818 M=0.201 S=0.308
#   push_y_neg   A=0.933 P=0.714 R=0.999 F1=0.833 M=0.191 S=0.301
#   lift_x       A=0.779 P=0.727 R=0.835 F1=0.777 M=0.506 S=0.167
#   lift_y       A=0.790 P=0.743 R=0.854 F1=0.795 M=0.517 S=0.175
#   pull_x       A=0.777 P=0.671 R=0.857 F1=0.753 M=0.489 S=0.171
#   pull_y       A=0.784 P=0.697 R=0.851 F1=0.766 M=0.499 S=0.177
# impacts: d=6.747 m=1.911 dist=5.700 q=2.101 | std: c1=0.146 c2=0.287 c3=0.206 c4=0.206 pool=0.110 quat=0.279 logit=3.287 | dead: conv=0.62 q=0.00
# epoch 82: tL=0.0330 vL=0.0333 lr=2.66e-05
#   push_x_pos   A=0.927 P=0.692 R=0.999 F1=0.817 M=0.187 S=0.302
#   push_x_neg   A=0.916 P=0.679 R=0.999 F1=0.808 M=0.208 S=0.314
#   push_y_pos   A=0.922 P=0.692 R=0.999 F1=0.818 M=0.200 S=0.307
#   push_y_neg   A=0.933 P=0.715 R=0.999 F1=0.833 M=0.191 S=0.300
#   lift_x       A=0.788 P=0.751 R=0.808 F1=0.779 M=0.490 S=0.168
#   lift_y       A=0.804 P=0.773 R=0.833 F1=0.802 M=0.502 S=0.177
#   pull_x       A=0.789 P=0.697 R=0.826 F1=0.756 M=0.475 S=0.172
#   pull_y       A=0.796 P=0.720 R=0.836 F1=0.774 M=0.486 S=0.179
# impacts: d=7.162 m=2.019 dist=5.733 q=1.965 | std: c1=0.149 c2=0.294 c3=0.208 c4=0.208 pool=0.113 quat=0.282 logit=3.135 | dead: conv=0.60 q=0.00
# epoch 83: tL=0.0329 vL=0.0335 lr=2.39e-05
#   push_x_pos   A=0.927 P=0.691 R=1.000 F1=0.817 M=0.187 S=0.302
#   push_x_neg   A=0.916 P=0.679 R=0.999 F1=0.808 M=0.207 S=0.313
#   push_y_pos   A=0.923 P=0.693 R=0.999 F1=0.819 M=0.201 S=0.307
#   push_y_neg   A=0.933 P=0.715 R=0.999 F1=0.833 M=0.190 S=0.301
#   lift_x       A=0.786 P=0.739 R=0.829 F1=0.782 M=0.500 S=0.167
#   lift_y       A=0.802 P=0.768 R=0.837 F1=0.801 M=0.505 S=0.177
#   pull_x       A=0.785 P=0.684 R=0.850 F1=0.758 M=0.484 S=0.172
#   pull_y       A=0.793 P=0.715 R=0.836 F1=0.771 M=0.488 S=0.178
# impacts: d=7.535 m=2.007 dist=5.787 q=2.047 | std: c1=0.149 c2=0.295 c3=0.213 c4=0.213 pool=0.115 quat=0.276 logit=3.187 | dead: conv=0.60 q=0.00
# epoch 84: tL=0.0329 vL=0.0334 lr=2.15e-05
#   push_x_pos   A=0.927 P=0.691 R=1.000 F1=0.817 M=0.185 S=0.300
#   push_x_neg   A=0.918 P=0.682 R=0.999 F1=0.810 M=0.204 S=0.311
#   push_y_pos   A=0.923 P=0.695 R=0.999 F1=0.820 M=0.198 S=0.305
#   push_y_neg   A=0.933 P=0.714 R=0.999 F1=0.833 M=0.188 S=0.299
#   lift_x       A=0.787 P=0.744 R=0.822 F1=0.781 M=0.495 S=0.168
#   lift_y       A=0.802 P=0.766 R=0.842 F1=0.802 M=0.504 S=0.177
#   pull_x       A=0.789 P=0.692 R=0.843 F1=0.760 M=0.478 S=0.172
#   pull_y       A=0.793 P=0.714 R=0.837 F1=0.771 M=0.486 S=0.179
# impacts: d=7.712 m=1.995 dist=5.826 q=2.079 | std: c1=0.151 c2=0.300 c3=0.212 c4=0.212 pool=0.115 quat=0.280 logit=3.234 | dead: conv=0.60 q=0.00
# epoch 85: tL=0.0327 vL=0.0332 lr=1.91e-05
#   push_x_pos   A=0.927 P=0.691 R=1.000 F1=0.817 M=0.185 S=0.301
#   push_x_neg   A=0.917 P=0.680 R=0.999 F1=0.809 M=0.206 S=0.312
#   push_y_pos   A=0.923 P=0.694 R=0.999 F1=0.819 M=0.200 S=0.306
#   push_y_neg   A=0.933 P=0.715 R=0.999 F1=0.833 M=0.188 S=0.299
#   lift_x       A=0.792 P=0.762 R=0.798 F1=0.780 M=0.483 S=0.171
#   lift_y       A=0.806 P=0.785 R=0.816 F1=0.800 M=0.493 S=0.179
#   pull_x       A=0.795 P=0.712 R=0.813 F1=0.759 M=0.467 S=0.174
#   pull_y       A=0.798 P=0.731 R=0.815 F1=0.771 M=0.476 S=0.180
# impacts: d=7.306 m=2.043 dist=5.952 q=2.053 | std: c1=0.149 c2=0.296 c3=0.211 c4=0.211 pool=0.113 quat=0.280 logit=3.185 | dead: conv=0.60 q=0.00
# epoch 86: tL=0.0327 vL=0.0335 lr=1.68e-05
#   push_x_pos   A=0.927 P=0.691 R=1.000 F1=0.817 M=0.185 S=0.302
#   push_x_neg   A=0.917 P=0.679 R=0.998 F1=0.808 M=0.206 S=0.313
#   push_y_pos   A=0.923 P=0.694 R=0.999 F1=0.819 M=0.200 S=0.307
#   push_y_neg   A=0.933 P=0.715 R=0.999 F1=0.833 M=0.189 S=0.300
#   lift_x       A=0.785 P=0.737 R=0.830 F1=0.781 M=0.501 S=0.170
#   lift_y       A=0.799 P=0.762 R=0.842 F1=0.800 M=0.507 S=0.178
#   pull_x       A=0.784 P=0.682 R=0.852 F1=0.757 M=0.483 S=0.174
#   pull_y       A=0.791 P=0.711 R=0.839 F1=0.770 M=0.488 S=0.180
# impacts: d=7.450 m=1.987 dist=5.939 q=2.078 | std: c1=0.149 c2=0.295 c3=0.210 c4=0.210 pool=0.113 quat=0.280 logit=3.256 | dead: conv=0.61 q=0.00
# epoch 87: tL=0.0327 vL=0.0333 lr=1.47e-05
#   push_x_pos   A=0.927 P=0.691 R=1.000 F1=0.817 M=0.185 S=0.302
#   push_x_neg   A=0.917 P=0.681 R=0.999 F1=0.810 M=0.205 S=0.313
#   push_y_pos   A=0.923 P=0.695 R=0.999 F1=0.820 M=0.199 S=0.307
#   push_y_neg   A=0.933 P=0.714 R=0.999 F1=0.833 M=0.188 S=0.300
#   lift_x       A=0.787 P=0.746 R=0.818 F1=0.780 M=0.494 S=0.172
#   lift_y       A=0.803 P=0.773 R=0.830 F1=0.800 M=0.501 S=0.180
#   pull_x       A=0.790 P=0.694 R=0.841 F1=0.761 M=0.477 S=0.176
#   pull_y       A=0.795 P=0.720 R=0.829 F1=0.771 M=0.483 S=0.182
# impacts: d=7.273 m=1.997 dist=6.054 q=2.028 | std: c1=0.147 c2=0.291 c3=0.208 c4=0.208 pool=0.112 quat=0.281 logit=3.223 | dead: conv=0.60 q=0.00
# epoch 88: tL=0.0327 vL=0.0334 lr=1.27e-05
#   push_x_pos   A=0.927 P=0.691 R=1.000 F1=0.817 M=0.186 S=0.302
#   push_x_neg   A=0.917 P=0.679 R=0.998 F1=0.808 M=0.206 S=0.313
#   push_y_pos   A=0.923 P=0.694 R=0.999 F1=0.819 M=0.200 S=0.307
#   push_y_neg   A=0.933 P=0.715 R=0.999 F1=0.833 M=0.189 S=0.300
#   lift_x       A=0.786 P=0.740 R=0.827 F1=0.781 M=0.498 S=0.170
#   lift_y       A=0.802 P=0.767 R=0.838 F1=0.801 M=0.506 S=0.178
#   pull_x       A=0.787 P=0.687 R=0.848 F1=0.759 M=0.481 S=0.174
#   pull_y       A=0.792 P=0.713 R=0.839 F1=0.771 M=0.488 S=0.180
# impacts: d=6.971 m=2.014 dist=6.015 q=2.092 | std: c1=0.148 c2=0.293 c3=0.209 c4=0.209 pool=0.112 quat=0.286 logit=3.269 | dead: conv=0.60 q=0.00
# epoch 89: tL=0.0325 vL=0.0332 lr=1.09e-05
#   push_x_pos   A=0.927 P=0.691 R=1.000 F1=0.817 M=0.185 S=0.300
#   push_x_neg   A=0.917 P=0.679 R=0.998 F1=0.808 M=0.205 S=0.311
#   push_y_pos   A=0.923 P=0.694 R=0.999 F1=0.819 M=0.199 S=0.305
#   push_y_neg   A=0.933 P=0.715 R=0.999 F1=0.833 M=0.189 S=0.298
#   lift_x       A=0.789 P=0.748 R=0.818 F1=0.781 M=0.493 S=0.169
#   lift_y       A=0.805 P=0.774 R=0.837 F1=0.804 M=0.502 S=0.177
#   pull_x       A=0.791 P=0.697 R=0.837 F1=0.760 M=0.476 S=0.173
#   pull_y       A=0.796 P=0.720 R=0.835 F1=0.773 M=0.485 S=0.179
# impacts: d=7.578 m=1.918 dist=5.914 q=2.105 | std: c1=0.150 c2=0.297 c3=0.213 c4=0.213 pool=0.114 quat=0.277 logit=3.208 | dead: conv=0.60 q=0.00
# epoch 90: tL=0.0326 vL=0.0332 lr=9.18e-06
#   push_x_pos   A=0.927 P=0.691 R=1.000 F1=0.817 M=0.186 S=0.301
#   push_x_neg   A=0.917 P=0.681 R=0.998 F1=0.809 M=0.205 S=0.312
#   push_y_pos   A=0.923 P=0.695 R=0.999 F1=0.820 M=0.199 S=0.306
#   push_y_neg   A=0.934 P=0.715 R=0.999 F1=0.834 M=0.189 S=0.299
#   lift_x       A=0.789 P=0.750 R=0.816 F1=0.782 M=0.492 S=0.171
#   lift_y       A=0.805 P=0.778 R=0.827 F1=0.802 M=0.498 S=0.180
#   pull_x       A=0.793 P=0.699 R=0.836 F1=0.762 M=0.475 S=0.175
#   pull_y       A=0.797 P=0.724 R=0.827 F1=0.772 M=0.481 S=0.181
# impacts: d=7.787 m=2.039 dist=5.936 q=2.025 | std: c1=0.151 c2=0.300 c3=0.213 c4=0.213 pool=0.116 quat=0.280 logit=3.198 | dead: conv=0.60 q=0.00
# epoch 91: tL=0.0327 vL=0.0331 lr=7.60e-06
#   push_x_pos   A=0.927 P=0.691 R=1.000 F1=0.817 M=0.186 S=0.300
#   push_x_neg   A=0.917 P=0.679 R=0.998 F1=0.808 M=0.204 S=0.311
#   push_y_pos   A=0.923 P=0.694 R=0.999 F1=0.819 M=0.199 S=0.305
#   push_y_neg   A=0.934 P=0.715 R=0.999 F1=0.834 M=0.189 S=0.299
#   lift_x       A=0.791 P=0.760 R=0.800 F1=0.780 M=0.484 S=0.171
#   lift_y       A=0.808 P=0.793 R=0.808 F1=0.801 M=0.490 S=0.180
#   pull_x       A=0.796 P=0.711 R=0.816 F1=0.760 M=0.468 S=0.174
#   pull_y       A=0.803 P=0.741 R=0.810 F1=0.774 M=0.472 S=0.181
# impacts: d=7.527 m=2.089 dist=6.011 q=2.098 | std: c1=0.151 c2=0.301 c3=0.213 c4=0.213 pool=0.114 quat=0.281 logit=3.181 | dead: conv=0.59 q=0.00
# epoch 92: tL=0.0325 vL=0.0334 lr=6.17e-06
#   push_x_pos   A=0.927 P=0.691 R=1.000 F1=0.817 M=0.186 S=0.301
#   push_x_neg   A=0.916 P=0.679 R=0.998 F1=0.808 M=0.205 S=0.312
#   push_y_pos   A=0.923 P=0.694 R=0.999 F1=0.819 M=0.199 S=0.306
#   push_y_neg   A=0.933 P=0.714 R=0.999 F1=0.833 M=0.189 S=0.300
#   lift_x       A=0.787 P=0.742 R=0.829 F1=0.783 M=0.499 S=0.169
#   lift_y       A=0.801 P=0.765 R=0.841 F1=0.801 M=0.507 S=0.178
#   pull_x       A=0.787 P=0.686 R=0.851 F1=0.759 M=0.482 S=0.173
#   pull_y       A=0.792 P=0.712 R=0.838 F1=0.770 M=0.489 S=0.179
# impacts: d=7.646 m=2.041 dist=6.017 q=2.069 | std: c1=0.151 c2=0.300 c3=0.214 c4=0.214 pool=0.116 quat=0.282 logit=3.227 | dead: conv=0.60 q=0.00
# epoch 93: tL=0.0326 vL=0.0332 lr=4.89e-06
#   push_x_pos   A=0.927 P=0.691 R=1.000 F1=0.817 M=0.186 S=0.301
#   push_x_neg   A=0.917 P=0.679 R=0.998 F1=0.808 M=0.205 S=0.312
#   push_y_pos   A=0.923 P=0.694 R=0.999 F1=0.819 M=0.199 S=0.306
#   push_y_neg   A=0.934 P=0.715 R=0.999 F1=0.834 M=0.189 S=0.299
#   lift_x       A=0.791 P=0.751 R=0.819 F1=0.783 M=0.493 S=0.170
#   lift_y       A=0.808 P=0.779 R=0.832 F1=0.805 M=0.499 S=0.179
#   pull_x       A=0.791 P=0.696 R=0.837 F1=0.760 M=0.476 S=0.174
#   pull_y       A=0.797 P=0.724 R=0.830 F1=0.773 M=0.482 S=0.180
# impacts: d=7.432 m=1.973 dist=6.064 q=2.140 | std: c1=0.148 c2=0.293 c3=0.209 c4=0.209 pool=0.112 quat=0.276 logit=3.235 | dead: conv=0.60 q=0.00
# epoch 94: tL=0.0325 vL=0.0332 lr=3.75e-06
#   push_x_pos   A=0.927 P=0.691 R=1.000 F1=0.817 M=0.186 S=0.301
#   push_x_neg   A=0.917 P=0.681 R=0.998 F1=0.809 M=0.204 S=0.312
#   push_y_pos   A=0.923 P=0.694 R=0.999 F1=0.819 M=0.199 S=0.306
#   push_y_neg   A=0.934 P=0.715 R=0.999 F1=0.834 M=0.189 S=0.299
#   lift_x       A=0.789 P=0.748 R=0.819 F1=0.782 M=0.494 S=0.170
#   lift_y       A=0.806 P=0.777 R=0.833 F1=0.804 M=0.500 S=0.179
#   pull_x       A=0.790 P=0.694 R=0.839 F1=0.760 M=0.477 S=0.174
#   pull_y       A=0.797 P=0.723 R=0.831 F1=0.773 M=0.482 S=0.180
# impacts: d=7.682 m=1.920 dist=5.918 q=2.062 | std: c1=0.150 c2=0.298 c3=0.213 c4=0.213 pool=0.115 quat=0.279 logit=3.144 | dead: conv=0.60 q=0.00
# epoch 95: tL=0.0325 vL=0.0333 lr=2.76e-06
#   push_x_pos   A=0.927 P=0.691 R=1.000 F1=0.817 M=0.185 S=0.301
#   push_x_neg   A=0.917 P=0.681 R=0.998 F1=0.810 M=0.205 S=0.312
#   push_y_pos   A=0.923 P=0.695 R=0.999 F1=0.820 M=0.199 S=0.306
#   push_y_neg   A=0.933 P=0.715 R=0.999 F1=0.833 M=0.189 S=0.299
#   lift_x       A=0.788 P=0.743 R=0.826 F1=0.782 M=0.497 S=0.170
#   lift_y       A=0.803 P=0.769 R=0.840 F1=0.803 M=0.504 S=0.178
#   pull_x       A=0.787 P=0.688 R=0.847 F1=0.759 M=0.480 S=0.174
#   pull_y       A=0.794 P=0.717 R=0.835 F1=0.772 M=0.486 S=0.180
# impacts: d=7.580 m=1.982 dist=6.024 q=2.110 | std: c1=0.151 c2=0.299 c3=0.214 c4=0.214 pool=0.115 quat=0.279 logit=3.256 | dead: conv=0.60 q=0.00
# epoch 96: tL=0.0326 vL=0.0333 lr=1.92e-06
#   push_x_pos   A=0.927 P=0.691 R=1.000 F1=0.817 M=0.186 S=0.301
#   push_x_neg   A=0.916 P=0.679 R=0.998 F1=0.808 M=0.205 S=0.313
#   push_y_pos   A=0.923 P=0.694 R=0.999 F1=0.819 M=0.199 S=0.306
#   push_y_neg   A=0.934 P=0.715 R=0.999 F1=0.834 M=0.189 S=0.300
#   lift_x       A=0.788 P=0.743 R=0.827 F1=0.783 M=0.497 S=0.170
#   lift_y       A=0.802 P=0.768 R=0.838 F1=0.801 M=0.504 S=0.179
#   pull_x       A=0.788 P=0.688 R=0.850 F1=0.761 M=0.481 S=0.174
#   pull_y       A=0.794 P=0.717 R=0.835 F1=0.772 M=0.486 S=0.180
# impacts: d=7.457 m=2.030 dist=6.105 q=2.200 | std: c1=0.150 c2=0.297 c3=0.211 c4=0.211 pool=0.115 quat=0.277 logit=3.319 | dead: conv=0.60 q=0.00
# epoch 97: tL=0.0325 vL=0.0332 lr=1.23e-06
#   push_x_pos   A=0.927 P=0.691 R=1.000 F1=0.817 M=0.185 S=0.301
#   push_x_neg   A=0.917 P=0.679 R=0.998 F1=0.808 M=0.205 S=0.312
#   push_y_pos   A=0.923 P=0.694 R=0.999 F1=0.819 M=0.199 S=0.306
#   push_y_neg   A=0.934 P=0.715 R=0.999 F1=0.834 M=0.189 S=0.299
#   lift_x       A=0.789 P=0.748 R=0.820 F1=0.782 M=0.494 S=0.170
#   lift_y       A=0.806 P=0.775 R=0.835 F1=0.804 M=0.501 S=0.179
#   pull_x       A=0.790 P=0.695 R=0.840 F1=0.760 M=0.477 S=0.174
#   pull_y       A=0.797 P=0.723 R=0.831 F1=0.773 M=0.483 S=0.180
# impacts: d=7.453 m=1.964 dist=6.033 q=2.131 | std: c1=0.150 c2=0.299 c3=0.213 c4=0.213 pool=0.114 quat=0.276 logit=3.243 | dead: conv=0.60 q=0.00
# epoch 98: tL=0.0326 vL=0.0332 lr=6.91e-07
#   push_x_pos   A=0.927 P=0.691 R=1.000 F1=0.817 M=0.185 S=0.301
#   push_x_neg   A=0.916 P=0.679 R=0.998 F1=0.808 M=0.205 S=0.312
#   push_y_pos   A=0.923 P=0.694 R=0.999 F1=0.819 M=0.199 S=0.306
#   push_y_neg   A=0.934 P=0.715 R=0.999 F1=0.834 M=0.189 S=0.299
#   lift_x       A=0.788 P=0.747 R=0.820 F1=0.782 M=0.494 S=0.170
#   lift_y       A=0.806 P=0.775 R=0.837 F1=0.805 M=0.501 S=0.179
#   pull_x       A=0.790 P=0.694 R=0.839 F1=0.760 M=0.478 S=0.174
#   pull_y       A=0.796 P=0.721 R=0.832 F1=0.772 M=0.483 S=0.180
# impacts: d=7.309 m=2.008 dist=6.023 q=2.120 | std: c1=0.151 c2=0.300 c3=0.212 c4=0.212 pool=0.114 quat=0.276 logit=3.180 | dead: conv=0.60 q=0.00
# epoch 99: tL=0.0325 vL=0.0332 lr=3.07e-07
#   push_x_pos   A=0.927 P=0.691 R=1.000 F1=0.817 M=0.185 S=0.301
#   push_x_neg   A=0.916 P=0.679 R=0.998 F1=0.808 M=0.205 S=0.312
#   push_y_pos   A=0.923 P=0.694 R=0.999 F1=0.819 M=0.199 S=0.306
#   push_y_neg   A=0.934 P=0.715 R=0.999 F1=0.834 M=0.189 S=0.299
#   lift_x       A=0.789 P=0.748 R=0.820 F1=0.782 M=0.494 S=0.170
#   lift_y       A=0.806 P=0.776 R=0.835 F1=0.804 M=0.501 S=0.179
#   pull_x       A=0.790 P=0.694 R=0.839 F1=0.760 M=0.477 S=0.174
#   pull_y       A=0.796 P=0.722 R=0.831 F1=0.772 M=0.483 S=0.180
# impacts: d=7.648 m=1.946 dist=6.116 q=2.050 | std: c1=0.151 c2=0.299 c3=0.213 c4=0.213 pool=0.115 quat=0.282 logit=3.193 | dead: conv=0.60 q=0.00
# epoch 100: tL=0.0325 vL=0.0332 lr=7.69e-08
#   push_x_pos   A=0.927 P=0.691 R=1.000 F1=0.817 M=0.185 S=0.301
#   push_x_neg   A=0.916 P=0.679 R=0.998 F1=0.808 M=0.205 S=0.312
#   push_y_pos   A=0.923 P=0.694 R=0.999 F1=0.819 M=0.199 S=0.306
#   push_y_neg   A=0.934 P=0.715 R=0.999 F1=0.834 M=0.189 S=0.299
#   lift_x       A=0.789 P=0.748 R=0.820 F1=0.782 M=0.494 S=0.170
#   lift_y       A=0.807 P=0.776 R=0.836 F1=0.805 M=0.501 S=0.179
#   pull_x       A=0.790 P=0.694 R=0.839 F1=0.760 M=0.477 S=0.174
#   pull_y       A=0.796 P=0.721 R=0.831 F1=0.772 M=0.483 S=0.180
# impacts: d=7.498 m=2.067 dist=6.112 q=2.108 | std: c1=0.151 c2=0.299 c3=0.212 c4=0.212 pool=0.114 quat=0.283 logit=3.312 | dead: conv=0.60 q=0.00

# %%
checkpoint = {
    "epoch": 100,
    "model_state_dict": model.state_dict(),
    "optimizer_state_dict": optimizer.state_dict(),
    "scheduler_state_dict": scheduler.state_dict(),
    "val_loss": val_loss,
    "avg_f1": avg_f1,
}

torch.save(checkpoint, "cnn-model-100.pt")
